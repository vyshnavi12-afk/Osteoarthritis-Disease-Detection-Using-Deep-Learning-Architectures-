# %%
import numpy as np
import pandas as pd
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import time
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
sns.set_style('darkgrid')
import shutil
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
test_path='/content/drive/MyDrive/test'
train_path='/content/drive/MyDrive/train'
valid_path='/content/drive/MyDrive/val'

# %%
list_of_classes=['Stage - I', 'Stage - IV', 'Stage - V', 'Stage - II', 'Stage - III']

for d in [train_path, test_path, valid_path]:
    filepaths = []
    labels=[] 
    classlist=os.listdir(d)   
    for klass in classlist:
        intklass=int(klass)
        label=list_of_classes[intklass]
        classpath=os.path.join(d, klass)
        flist=os.listdir(classpath)        
        for f in flist:
            fpath=os.path.join(classpath,f)
            filepaths.append(fpath)
            labels.append(label)
    Fseries=pd.Series(filepaths, name='filepaths')
    Lseries=pd.Series(labels, name='labels')        
    pdf=pd.concat([Fseries, Lseries], axis=1)
    if d == test_path:
        test_df=pdf
    elif d == valid_path:
        valid_df=pdf
    else:
        train_df=pdf
print('train_df lenght: ', len(train_df), '  test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
# get the number of classes and the images count for each class in train_df
classes=sorted(list(train_df['labels'].unique()))
class_count = len(classes)
print('The number of classes in the dataset is: ', class_count)
groups=train_df.groupby('labels')
print('{0:^30s} {1:^13s}'.format('CLASS', 'IMAGE COUNT'))
countlist=[]
classlist=[]
for label in sorted(list(train_df['labels'].unique())):
    group=groups.get_group(label)
    countlist.append(len(group))
    classlist.append(label)
    print('{0:^30s} {1:^13s}'.format(label, str(len(group))))

# get the classes with the minimum and maximum number of train images
max_value=np.max(countlist)
max_index=countlist.index(max_value)
max_class=classlist[max_index]
min_value=np.min(countlist)
min_index=countlist.index(min_value)
min_class=classlist[min_index]
print(max_class, ' has the most images= ',max_value, ' ', min_class, ' has the least images= ', min_value)
# lets get the average height and width of a sample of the train images
ht=0
wt=0
# select 100 random samples of train_df
train_df_sample=train_df.sample(n=100, random_state=123,axis=0)
for i in range (len(train_df_sample)):
    fpath=train_df_sample['filepaths'].iloc[i]
    img=plt.imread(fpath)
    shape=img.shape
    ht += shape[0]
    wt += shape[1]
print('average height= ', ht//100, ' average width= ', wt//100, 'aspect ratio= ', ht/wt)
# Out:
# train_df lenght:  5778   test_df length:  1656   valid_df length:  826
# The number of classes in the dataset is:  5
#             CLASS               IMAGE COUNT
#           Stage - I                2286
#           Stage - II                757
#          Stage - III                173
#           Stage - IV               1046
#           Stage - V                1516
# Stage - I  has the most images=  2286   Stage - III  has the least images=  173
# average height=  224  average width=  224 aspect ratio=  1.0

# %%
def trim(df, max_samples, min_samples, column):
    df=df.copy()
    groups=df.groupby(column)    
    trimmed_df = pd.DataFrame(columns = df.columns)
    groups=df.groupby(column)
    for label in df[column].unique(): 
        group=groups.get_group(label)
        count=len(group)    
        if count > max_samples:
            sampled_group=group.sample(n=max_samples, random_state=123,axis=0)
            trimmed_df=pd.concat([trimmed_df, sampled_group], axis=0)
        else:
            if count>=min_samples:
                sampled_group=group        
                trimmed_df=pd.concat([trimmed_df, sampled_group], axis=0)
    print('after trimming, the maximum samples in any class is now ',max_samples, ' and the minimum samples in any class is ', min_samples)
    return trimmed_df

max_samples=500 # since each class has more than 200 images all classes will be trimmed to have 200 images per class
min_samples=173
column='labels'
train_df= trim(train_df, max_samples, min_samples, column)
# Out:
# after trimming, the maximum samples in any class is now  500  and the minimum samples in any class is  173

# %%
def balance(df, n, working_dir, img_size):
    df=df.copy()
    print('Initial length of dataframe is ', len(df))
    aug_dir=os.path.join(working_dir, 'aug')# directory to store augmented images
    if os.path.isdir(aug_dir):# start with an empty directory
        shutil.rmtree(aug_dir)
    os.mkdir(aug_dir)        
    for label in df['labels'].unique():    
        dir_path=os.path.join(aug_dir,label)    
        os.mkdir(dir_path) # make class directories within aug directory
    # create and store the augmented images  
    total=0
    gen=ImageDataGenerator(horizontal_flip=True,  rotation_range=20, width_shift_range=.2,
                                  height_shift_range=.2, zoom_range=.2)
    groups=df.groupby('labels') # group by class
    for label in df['labels'].unique():  # for every class               
        group=groups.get_group(label)  # a dataframe holding only rows with the specified label 
        sample_count=len(group)   # determine how many samples there are in this class  
        if sample_count< n: # if the class has less than target number of images
            aug_img_count=0
            delta=n - sample_count  # number of augmented images to create
            target_dir=os.path.join(aug_dir, label)  # define where to write the images
            msg='{0:40s} for class {1:^30s} creating {2:^5s} augmented images'.format(' ', label, str(delta))
            print(msg, '\r', end='') # prints over on the same line
            aug_gen=gen.flow_from_dataframe( group,  x_col='filepaths', y_col=None, target_size=img_size,
                                            class_mode=None, batch_size=1, shuffle=False, 
                                            save_to_dir=target_dir, save_prefix='aug-', color_mode='rgb',
                                            save_format='jpg')
            while aug_img_count<delta:
                images=next(aug_gen)            
                aug_img_count += len(images)
            total +=aug_img_count
    print('Total Augmented images created= ', total)
    # create aug_df and merge with train_df to create composite training set ndf
    aug_fpaths=[]
    aug_labels=[]
    classlist=os.listdir(aug_dir)
    for klass in classlist:
        classpath=os.path.join(aug_dir, klass)     
        flist=os.listdir(classpath)    
        for f in flist:        
            fpath=os.path.join(classpath,f)         
            aug_fpaths.append(fpath)
            aug_labels.append(klass)
    Fseries=pd.Series(aug_fpaths, name='filepaths')
    Lseries=pd.Series(aug_labels, name='labels')
    aug_df=pd.concat([Fseries, Lseries], axis=1)         
    df=pd.concat([df,aug_df], axis=0).reset_index(drop=True)
    print('Length of augmented dataframe is now ', len(df))
    return df 

n=500 # number of samples in each class
working_dir=r'./' # directory to store augmented images
img_size=(224,224) # size of augmented images
train_df=balance(train_df, n, working_dir, img_size)
# Out:
# Initial length of dataframe is  2173
# Found 173 validated image filenames.
# Total Augmented images created=  327
# Length of augmented dataframe is now  2500

# %%
def relabel(label_in):
    if label_in =='Stage - I' or label_in == 'Stage - IV' or label_in =='Stage - V':
        label='Stage - I'
    else:
        label=label_in
    return label


for df in [train_df, test_df, valid_df]:
    for i in range (len(df)):
        label=df['labels'].iloc[i]
        new_label=relabel(label)
        df['labels'].iloc[i]=new_label

# %%
print (train_df['labels'].value_counts())
# Out:
# Stage - I      1500
# Stage - II      500
# Stage - III     500
# Name: labels, dtype: int64

# %%
max_samples=500 # since each class has more than 200 images all classes will be trimmed to have 200 images per class
min_samples=500
column='labels'
train_df= trim(train_df, max_samples, min_samples, column)
# Out:
# after trimming, the maximum samples in any class is now  500  and the minimum samples in any class is  500

# %%
batch_size=20 # We will use and EfficientetB3 model, with image size of (200, 250) this size should not cause resource error
trgen=ImageDataGenerator(horizontal_flip=True,rotation_range=20 )
t_and_v_gen=ImageDataGenerator()
msg='{0:70s} for train generator'.format(' ')
print(msg, '\r', end='') # prints over on the same line
train_gen=trgen.flow_from_dataframe(train_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
msg='{0:70s} for valid generator'.format(' ')
print(msg, '\r', end='') # prints over on the same line
valid_gen=t_and_v_gen.flow_from_dataframe(valid_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)
# for the test_gen we want to calculate the batch size and test steps such that batch_size X test_steps= number of samples in test set
# this insures that we go through all the sample in the test set exactly once.
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]  
test_steps=int(length/test_batch_size)
msg='{0:70s} for test generator'.format(' ')
print(msg, '\r', end='') # prints over on the same line
test_gen=t_and_v_gen.flow_from_dataframe(test_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=test_batch_size)
# from the generator we can get information we will need later
classes=list(train_gen.class_indices.keys())
class_indices=list(train_gen.class_indices.values())
class_count=len(classes)
labels=test_gen.labels
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)
# Out:
# Found 1500 validated image filenames belonging to 3 classes.
# Found 826 validated image filenames belonging to 3 classes.
# Found 1656 validated image filenames belonging to 3 classes.
# test batch size:  72   test steps:  23  number of classes :  3

# %%
def show_image_samples(gen ):
    t_dict=gen.class_indices
    classes=list(t_dict.keys())    
    images,labels=next(gen) # get a sample batch from the generator 
    plt.figure(figsize=(18, 18))
    length=len(labels)
    if length<25:   #show maximum of 25 images
        r=length
    else:
        r=25
    for i in range(r):        
        plt.subplot(5, 5, i + 1)
        image=images[i] /255       
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='green', fontsize=15)
        plt.axis('off')
    plt.show()
show_image_samples(train_gen )

# %%
pip install tf-nightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tf-nightly
#   Downloading tf_nightly-2.12.0.dev20221209-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (558.0 MB)
#      |████████████████████████████████| 558.0 MB 21 kB/s
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tf-nightly) (1.51.1)
# Collecting tf-estimator-nightly~=2.12.0.dev
#   Downloading tf_estimator_nightly-2.12.0.dev2022120909-py2.py3-none-any.whl (439 kB)
#      |████████████████████████████████| 439 kB 65.8 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tf-nightly) (57.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tf-nightly) (2.1.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tf-nightly) (1.14.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tf-nightly) (0.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tf-nightly) (1.3.0)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-22.12.6-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from tf-nightly) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tf-nightly) (4.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tf-nightly) (3.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tf-nightly) (1.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tf-nightly) (21.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tf-nightly) (3.19.6)
# Collecting tb-nightly~=2.12.0.a
#   Downloading tb_nightly-2.12.0a20221209-py3-none-any.whl (5.7 MB)
#      |████████████████████████████████| 5.7 MB 5.3 MB/s
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tf-nightly) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tf-nightly) (0.28.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tf-nightly) (14.0.6)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tf-nightly) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tf-nightly) (0.2.0)
# Collecting keras-nightly~=2.12.0.dev
#   Downloading keras_nightly-2.12.0.dev2022120908-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 34.6 MB/s
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.8/dist-packages (from tf-nightly) (0.3.25)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tf-nightly) (0.38.4)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.8/dist-packages (from jax>=0.3.15->tf-nightly) (1.7.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tb-nightly~=2.12.0.a->tf-nightly) (2.15.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tb-nightly~=2.12.0.a->tf-nightly) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tb-nightly~=2.12.0.a->tf-nightly) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tb-nightly~=2.12.0.a->tf-nightly) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tb-nightly~=2.12.0.a->tf-nightly) (2.23.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tb-nightly~=2.12.0.a->tf-nightly) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tb-nightly~=2.12.0.a->tf-nightly) (3.4.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.12.0.a->tf-nightly) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.12.0.a->tf-nightly) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.12.0.a->tf-nightly) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tb-nightly~=2.12.0.a->tf-nightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tb-nightly~=2.12.0.a->tf-nightly) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tb-nightly~=2.12.0.a->tf-nightly) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tb-nightly~=2.12.0.a->tf-nightly) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tb-nightly~=2.12.0.a->tf-nightly) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tb-nightly~=2.12.0.a->tf-nightly) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tb-nightly~=2.12.0.a->tf-nightly) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tb-nightly~=2.12.0.a->tf-nightly) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tb-nightly~=2.12.0.a->tf-nightly) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tf-nightly) (3.0.9)
# Installing collected packages: tf-estimator-nightly, tb-nightly, keras-nightly, flatbuffers, tf-nightly
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 1.12
#     Uninstalling flatbuffers-1.12:
#       Successfully uninstalled flatbuffers-1.12
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.9.2 requires flatbuffers<2,>=1.12, but you have flatbuffers 22.12.6 which is incompatible.
# Successfully installed flatbuffers-22.12.6 keras-nightly-2.12.0.dev2022120908 tb-nightly-2.12.0a20221209 tf-estimator-nightly-2.12.0.dev2022120909 tf-nightly-2.12.0.dev20221209

# %%
from tensorflow.keras.applications.efficientnet import EfficientNetB7
img_shape=(img_size[0], img_size[1], 3)
model_name='EfficientNetB7'
base_model=EfficientNetB7(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max') 
# Note you are always told NOT to make the base model trainable initially- that is WRONG you get better results leaving it trainable
base_model.trainable=True
x=base_model.output
x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
x=Dropout(rate=.4, seed=123)(x)       
output=Dense(class_count, activation='softmax')(x)
model=Model(inputs=base_model.input, outputs=output)
lr=.001 # start with this learning rate
model.compile(Adamax(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 179339264/258076736 [===================>..........] - ETA: 2s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-ce16089f8cfe> in <module>
#       2 img_shape=(img_size[0], img_size[1], 3)
#       3 model_name='EfficientNetB7'
# ----> 4 base_model=EfficientNetB7(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max')
#       5 # Note you are always told NOT to make the base model trainable initially- that is WRONG you get better results leaving it trainable
#       6 base_model.trainable=True
#
# /usr/local/lib/python3.8/dist-packages/keras/applications/efficientnet.py in EfficientNetB7(include_top, weights, input_tensor, input_shape, pooling, classes, classifier_activation, **kwargs)
#     728                    classifier_activation='softmax',
#     729                    **kwargs):
# --> 730   return EfficientNet(
#     731       2.0,
#     732       3.1,
#
# /usr/local/lib/python3.8/dist-packages/keras/applications/efficientnet.py in EfficientNet(width_coefficient, depth_coefficient, default_size, dropout_rate, drop_connect_rate, depth_divisor, activation, blocks_args, model_name, include_top, weights, input_tensor, input_shape, pooling, classes, classifier_activation)
#     417       file_hash = WEIGHTS_HASHES[model_name[-2:]][1]
#     418     file_name = model_name + file_suffix
# --> 419     weights_path = data_utils.get_file(
#     420         file_name,
#     421         BASE_WEIGHTS_PATH + file_name,
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/data_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     281     try:
#     282       try:
# --> 283         urlretrieve(origin, fpath, DLProgbar())
#     284       except urllib.error.HTTPError as e:
#     285         raise Exception(error_msg.format(origin, e.code, e.msg))
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/data_utils.py in urlretrieve(url, filename, reporthook, data)
#      82     response = urlopen(url, data)
#      83     with open(filename, 'wb') as fd:
# ---> 84       for chunk in chunk_read(response, reporthook=reporthook):
#      85         fd.write(chunk)
#      86 else:
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/data_utils.py in chunk_read(response, chunk_size, reporthook)
#      71       count = 0
#      72       while True:
# ---> 73         chunk = response.read(chunk_size)
#      74         count += 1
#      75         if reporthook is not None:
#
# /usr/lib/python3.8/http/client.py in read(self, amt)
#     457             # Amount is given, implement using readinto
#     458             b = bytearray(amt)
# --> 459             n = self.readinto(b)
#     460             return memoryview(b)[:n].tobytes()
#     461         else:
#
# /usr/lib/python3.8/http/client.py in readinto(self, b)
#     501         # connection, and the user is reading more bytes than will be provided
#     502         # (for example, reading in 1k chunks)
# --> 503         n = self.fp.readinto(b)
#     504         if not n and b:
#     505             # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /usr/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
K.clear_session() #clear the session
tf.compat.v1.reset_default_graph()
from tensorflow.keras.applications.efficientnet import EfficientNetB7
img_shape=(img_size[0], img_size[1], 3)
model_name='EfficientNetB7'
base_model=EfficientNetB7(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max')

base_model.trainable=True
x=base_model.output
x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
x=Dropout(rate=.4, seed=123)(x)       
output=Dense(class_count, activation='softmax')(x)
model=Model(inputs=base_model.input, outputs=output)
lr=.001 # start with this learning rate
model.compile(Adamax(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
class LR_ASK(keras.callbacks.Callback):
    def __init__ (self, model, epochs,  ask_epoch): # initialization of the callback
        super(LR_ASK, self).__init__()
        self.model=model               
        self.ask_epoch=ask_epoch
        self.epochs=epochs
        self.ask=True # if True query the user on a specified epoch
        self.lowest_vloss=np.inf
        self.best_weights=self.model.get_weights() # set best weights to model's initial weights
        self.best_epoch=1
        
        
    def on_train_begin(self, logs=None): # this runs on the beginning of training
        if self.ask_epoch == 0: 
            print('you set ask_epoch = 0, ask_epoch will be set to 1', flush=True)
            self.ask_epoch=1
        if self.ask_epoch >= self.epochs: # you are running for epochs but ask_epoch>epochs
            print('ask_epoch >= epochs, will train for ', epochs, ' epochs', flush=True)
            self.ask=False # do not query the user
        if self.epochs == 1:
            self.ask=False # running only for 1 epoch so do not query user
        else:
            print('Training will proceed until epoch', ask_epoch,' then you will be asked to') 
            print(' enter H to halt training or enter an integer for how many more epochs to run then be asked again')  
        self.start_time= time.time() # set the time at which training started
        
    def on_train_end(self, logs=None):   # runs at the end of training  
        print('loading model with weights from epoch ', self.best_epoch)
        self.model.set_weights(self.best_weights) # set the weights of the model to the best weights
        tr_duration=time.time() - self.start_time   # determine how long the training cycle lasted         
        hours = tr_duration // 3600
        minutes = (tr_duration - (hours * 3600)) // 60
        seconds = tr_duration - ((hours * 3600) + (minutes * 60))
        msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
        print (msg, flush=True) # print out training duration time
        
    def on_epoch_end(self, epoch, logs=None):  # method runs on the end of each epoch
        v_loss=logs.get('val_loss')  # get the validation loss for this epoch
        if v_loss< self.lowest_vloss:
            self.lowest_vloss=v_loss
            self.best_weights=self.model.get_weights() # set best weights to model's initial weights
            self.best_epoch=epoch + 1
            print (f'\n validation loss of {v_loss:7.4f} is below lowest loss, saving weights from epoch {str(epoch + 1):3s} as best weights')
        else:
            print (f'\n validation loss of {v_loss:7.4f} is above lowest loss of {self.lowest_vloss:7.4f} keeping weights from epoch {str(self.best_epoch)} as best weights')
        
        if self.ask: # are the conditions right to query the user?
            if epoch + 1 ==self.ask_epoch: # is this epoch the one for quering the user?
                print('\n Enter H to end training or  an integer for the number of additional epochs to run then ask again')
                ans=input()
                
                if ans == 'H' or ans =='h' or ans == '0': # quit training for these conditions
                    print ('you entered ', ans, ' Training halted on epoch ', epoch+1, ' due to user input\n', flush=True)
                    self.model.stop_training = True # halt training
                else: # user wants to continue training
                    self.ask_epoch += int(ans)
                    if self.ask_epoch > self.epochs:
                        print('\nYou specified maximum epochs of as ', self.epochs, ' cannot train for ', self.ask_epoch, flush =True)
                    else:
                        print ('you entered ', ans, ' Training will continue to epoch ', self.ask_epoch, flush=True)
                        lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
                        print(f'current LR is  {lr:7.5f}  hit enter to keep  this LR or enter a new LR')
                        ans=input(' ')
                        if ans =='':
                            print (f'keeping current LR of {lr:7.5f}')
                        else:
                            new_lr=float(ans)
                            tf.keras.backend.set_value(self.model.optimizer.lr, new_lr) # set the learning rate in the optimizer
                            print(' changing LR to ', ans)

# %%
epochs=40
ask_epoch=10
ask=LR_ASK(model, epochs,  ask_epoch)
#rlronp=tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2,verbose=1)
#callbacks=[rlronp, ask]
callbacks=[ask]

# %%
new_history=model.fit(x=train_gen,  epochs=epochs, verbose=1, callbacks=callbacks,  validation_data=valid_gen,
               validation_steps=None,  shuffle=False,  initial_epoch=0)
# Out:
# Training will proceed until epoch 10  then you will be asked to
#  enter H to halt training or enter an integer for how many more epochs to run then be asked again
# Epoch 1/40
# 75/75 [==============================] - ETA: 0s - loss: 8.7641 - accuracy: 0.5953
#  validation loss of  8.6368 is below lowest loss, saving weights from epoch 1   as best weights
# 75/75 [==============================] - 560s 7s/step - loss: 8.7641 - accuracy: 0.5953 - val_loss: 8.6368 - val_accuracy: 0.8511
# Epoch 2/40
# 75/75 [==============================] - ETA: 0s - loss: 6.5975 - accuracy: 0.7773
#  validation loss of  9.4042 is above lowest loss of  8.6368 keeping weights from epoch 1 as best weights
# 75/75 [==============================] - 96s 1s/step - loss: 6.5975 - accuracy: 0.7773 - val_loss: 9.4042 - val_accuracy: 0.9068
# Epoch 3/40
# 75/75 [==============================] - ETA: 0s - loss: 5.3152 - accuracy: 0.8700
#  validation loss of  5.2971 is below lowest loss, saving weights from epoch 3   as best weights
# 75/75 [==============================] - 96s 1s/step - loss: 5.3152 - accuracy: 0.8700 - val_loss: 5.2971 - val_accuracy: 0.8111
# Epoch 4/40
# 75/75 [==============================] - ETA: 0s - loss: 4.5706 - accuracy: 0.8880
#  validation loss of  4.2582 is below lowest loss, saving weights from epoch 4   as best weights
# 75/75 [==============================] - 97s 1s/step - loss: 4.5706 - accuracy: 0.8880 - val_loss: 4.2582 - val_accuracy: 0.9383
# Epoch 5/40
# 75/75 [==============================] - ETA: 0s - loss: 3.8890 - accuracy: 0.8940
#  validation loss of  3.5676 is below lowest loss, saving weights from epoch 5   as best weights
# 75/75 [==============================] - 96s 1s/step - loss: 3.8890 - accuracy: 0.8940 - val_loss: 3.5676 - val_accuracy: 0.9068
# Epoch 6/40
# 75/75 [==============================] - ETA: 0s - loss: 3.4303 - accuracy: 0.9053
#  validation loss of  3.1970 is below lowest loss, saving weights from epoch 6   as best weights
# 75/75 [==============================] - 96s 1s/step - loss: 3.4303 - accuracy: 0.9053 - val_loss: 3.1970 - val_accuracy: 0.9140
# Epoch 7/40
# 75/75 [==============================] - ETA: 0s - loss: 2.9559 - accuracy: 0.9160
#  validation loss of  2.8143 is below lowest loss, saving weights from epoch 7   as best weights
# 75/75 [==============================] - 96s 1s/step - loss: 2.9559 - accuracy: 0.9160 - val_loss: 2.8143 - val_accuracy: 0.9068
# Epoch 8/40
# 75/75 [==============================] - ETA: 0s - loss: 2.5420 - accuracy: 0.9273
#  validation loss of  2.5416 is below lowest loss, saving weights from epoch 8   as best weights
# 75/75 [==============================] - 96s 1s/step - loss: 2.5420 - accuracy: 0.9273 - val_loss: 2.5416 - val_accuracy: 0.9165
# Epoch 9/40
# 75/75 [==============================] - ETA: 0s - loss: 2.2097 - accuracy: 0.9453
#  validation loss of  2.0840 is below lowest loss, saving weights from epoch 9   as best weights
# 75/75 [==============================] - 97s 1s/step - loss: 2.2097 - accuracy: 0.9453 - val_loss: 2.0840 - val_accuracy: 0.9395
# Epoch 10/40
# 75/75 [==============================] - ETA: 0s - loss: 1.9203 - accuracy: 0.9440
#  validation loss of  2.0597 is below lowest loss, saving weights from epoch 10  as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# 10
# you entered  10  Training will continue to epoch  20
# current LR is  0.00100  hit enter to keep  this LR or enter a new LR
#  0.0005
#  changing LR to  0.0005
# 75/75 [==============================] - 164s 2s/step - loss: 1.9203 - accuracy: 0.9440 - val_loss: 2.0597 - val_accuracy: 0.8656
# Epoch 11/40
# 75/75 [==============================] - ETA: 0s - loss: 1.7027 - accuracy: 0.9580
#  validation loss of  1.7197 is below lowest loss, saving weights from epoch 11  as best weights
# 75/75 [==============================] - 97s 1s/step - loss: 1.7027 - accuracy: 0.9580 - val_loss: 1.7197 - val_accuracy: 0.9395
# Epoch 12/40
# 75/75 [==============================] - ETA: 0s - loss: 1.5984 - accuracy: 0.9527
#  validation loss of  1.6136 is below lowest loss, saving weights from epoch 12  as best weights
# 75/75 [==============================] - 96s 1s/step - loss: 1.5984 - accuracy: 0.9527 - val_loss: 1.6136 - val_accuracy: 0.9358
# Epoch 13/40
# 75/75 [==============================] - ETA: 0s - loss: 1.4611 - accuracy: 0.9713
#  validation loss of  1.5392 is below lowest loss, saving weights from epoch 13  as best weights
# 75/75 [==============================] - 96s 1s/step - loss: 1.4611 - accuracy: 0.9713 - val_loss: 1.5392 - val_accuracy: 0.9140
# Epoch 14/40
# 75/75 [==============================] - ETA: 0s - loss: 1.3735 - accuracy: 0.9687
#  validation loss of  1.4325 is below lowest loss, saving weights from epoch 14  as best weights
# 75/75 [==============================] - 96s 1s/step - loss: 1.3735 - accuracy: 0.9687 - val_loss: 1.4325 - val_accuracy: 0.9286
# Epoch 15/40
# 75/75 [==============================] - ETA: 0s - loss: 1.2531 - accuracy: 0.9733
#  validation loss of  1.3433 is below lowest loss, saving weights from epoch 15  as best weights
# 75/75 [==============================] - 97s 1s/step - loss: 1.2531 - accuracy: 0.9733 - val_loss: 1.3433 - val_accuracy: 0.9262
# Epoch 16/40
# 75/75 [==============================] - ETA: 0s - loss: 1.1763 - accuracy: 0.9680
#  validation loss of  1.2095 is below lowest loss, saving weights from epoch 16  as best weights
# 75/75 [==============================] - 96s 1s/step - loss: 1.1763 - accuracy: 0.9680 - val_loss: 1.2095 - val_accuracy: 0.9334
# Epoch 17/40
# 75/75 [==============================] - ETA: 0s - loss: 1.0693 - accuracy: 0.9793
#  validation loss of  1.2770 is above lowest loss of  1.2095 keeping weights from epoch 16 as best weights
# 75/75 [==============================] - 96s 1s/step - loss: 1.0693 - accuracy: 0.9793 - val_loss: 1.2770 - val_accuracy: 0.8959
# Epoch 18/40
# 75/75 [==============================] - ETA: 0s - loss: 0.9685 - accuracy: 0.9833
#  validation loss of  1.0820 is below lowest loss, saving weights from epoch 18  as best weights
# 75/75 [==============================] - 96s 1s/step - loss: 0.9685 - accuracy: 0.9833 - val_loss: 1.0820 - val_accuracy: 0.9201
# Epoch 19/40
# 75/75 [==============================] - ETA: 0s - loss: 0.9129 - accuracy: 0.9747
#  validation loss of  1.0096 is below lowest loss, saving weights from epoch 19  as best weights
# 75/75 [==============================] - 96s 1s/step - loss: 0.9129 - accuracy: 0.9747 - val_loss: 1.0096 - val_accuracy: 0.9177
# Epoch 20/40
# 75/75 [==============================] - ETA: 0s - loss: 0.8436 - accuracy: 0.9820
#  validation loss of  0.9349 is below lowest loss, saving weights from epoch 20  as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# H
# you entered  H  Training halted on epoch  20  due to user input
#
# 75/75 [==============================] - 105s 1s/step - loss: 0.8436 - accuracy: 0.9820 - val_loss: 0.9349 - val_accuracy: 0.9310
# loading model with weights from epoch  20
# training elapsed time was 0.0 hours, 41.0 minutes, 6.40 seconds)

# %%
model.evaluate(test_gen)
# Out:
# 23/23 [==============================] - 18s 759ms/step - loss: 0.9164 - accuracy: 0.9396
# [0.9163689613342285, 0.9396135210990906]

# %%
def predictor(test_gen, test_steps):
    y_pred= []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(test_gen, verbose=1)
    tests=len(preds)    
    for i, p in enumerate(preds):        
        pred_index=np.argmax(p)         
        true_index=test_gen.labels[i]  # labels are integer values        
        if pred_index != true_index: # a misclassification has occurred                                           
            errors=errors + 1
            file=test_gen.filenames[i]            
        y_pred.append(pred_index)
            
    acc=( 1-errors/tests) * 100
    print(f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}')
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    if class_count <=30:
        cm = confusion_matrix(ytrue, ypred )
        # plot the confusion matrix
        plt.figure(figsize=(12, 8))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
        plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4) # create classification report
    print("Classification Report:\n----------------------\n", clr)
    return errors, tests
errors, tests=predictor(test_gen, test_steps)
# Out:
# 23/23 [==============================] - 17s 760ms/step
# there were 100 errors in 1656 tests for an accuracy of  93.96
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#    Stage - I     0.9787    0.9624    0.9704      1382
#   Stage - II     0.7605    0.8117    0.7852       223
#  Stage - III     0.7627    0.8824    0.8182        51
#
#     accuracy                         0.9396      1656
#    macro avg     0.8340    0.8855    0.8580      1656
# weighted avg     0.9426    0.9396    0.9408      1656

# %%
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=1.0)
plt.plot(history.history['val_loss'],'b',linewidth=1.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=10)
plt.xlabel('Epochs ',fontsize=10)
plt.ylabel('Loss',fontsize=10)
plt.title('Loss Curves',fontsize=10)
plt.show()
#Plot the Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=1.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=1.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=10)
plt.xlabel('Epochs ',fontsize=10)
plt.ylabel('Accuracy',fontsize=10)
plt.title('Accuracy Curves',fontsize=10) 
plt.show()

# %%
tf.compat.v1.reset_default_graph()
from tensorflow.keras.applications import EfficientNetV2L
img_shape=(img_size[0], img_size[1], 3)
model_name='EfficientNetV2L'
base_model=EfficientNetV2L(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max')

base_model.trainable=True
x=base_model.output
x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
x=Dropout(rate=.4, seed=123)(x)       
output=Dense(class_count, activation='softmax')(x)
model=Model(inputs=base_model.input, outputs=output)
lr=.001 # start with this learning rate
model.compile(Adamax(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-l_notop.h5
# 473176280/473176280 [==============================] - 24s 0us/step

# %%
class LR_ASK(keras.callbacks.Callback):
    def __init__ (self, model, epochs,  ask_epoch): # initialization of the callback
        super(LR_ASK, self).__init__()
        self.model=model               
        self.ask_epoch=ask_epoch
        self.epochs=epochs
        self.ask=True # if True query the user on a specified epoch
        self.lowest_vloss=np.inf
        self.best_weights=self.model.get_weights() # set best weights to model's initial weights
        self.best_epoch=1
        
        
    def on_train_begin(self, logs=None): # this runs on the beginning of training
        if self.ask_epoch == 0: 
            print('you set ask_epoch = 0, ask_epoch will be set to 1', flush=True)
            self.ask_epoch=1
        if self.ask_epoch >= self.epochs: # you are running for epochs but ask_epoch>epochs
            print('ask_epoch >= epochs, will train for ', epochs, ' epochs', flush=True)
            self.ask=False # do not query the user
        if self.epochs == 1:
            self.ask=False # running only for 1 epoch so do not query user
        else:
            print('Training will proceed until epoch', ask_epoch,' then you will be asked to') 
            print(' enter H to halt training or enter an integer for how many more epochs to run then be asked again')  
        self.start_time= time.time() # set the time at which training started
        
    def on_train_end(self, logs=None):   # runs at the end of training  
        print('loading model with weights from epoch ', self.best_epoch)
        self.model.set_weights(self.best_weights) # set the weights of the model to the best weights
        tr_duration=time.time() - self.start_time   # determine how long the training cycle lasted         
        hours = tr_duration // 3600
        minutes = (tr_duration - (hours * 3600)) // 60
        seconds = tr_duration - ((hours * 3600) + (minutes * 60))
        msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
        print (msg, flush=True) # print out training duration time
        
    def on_epoch_end(self, epoch, logs=None):  # method runs on the end of each epoch
        v_loss=logs.get('val_loss')  # get the validation loss for this epoch
        if v_loss< self.lowest_vloss:
            self.lowest_vloss=v_loss
            self.best_weights=self.model.get_weights() # set best weights to model's initial weights
            self.best_epoch=epoch + 1
            print (f'\n validation loss of {v_loss:7.4f} is below lowest loss, saving weights from epoch {str(epoch + 1):3s} as best weights')
        else:
            print (f'\n validation loss of {v_loss:7.4f} is above lowest loss of {self.lowest_vloss:7.4f} keeping weights from epoch {str(self.best_epoch)} as best weights')
        
        if self.ask: # are the conditions right to query the user?
            if epoch + 1 ==self.ask_epoch: # is this epoch the one for quering the user?
                print('\n Enter H to end training or  an integer for the number of additional epochs to run then ask again')
                ans=input()
                
                if ans == 'H' or ans =='h' or ans == '0': # quit training for these conditions
                    print ('you entered ', ans, ' Training halted on epoch ', epoch+1, ' due to user input\n', flush=True)
                    self.model.stop_training = True # halt training
                else: # user wants to continue training
                    self.ask_epoch += int(ans)
                    if self.ask_epoch > self.epochs:
                        print('\nYou specified maximum epochs of as ', self.epochs, ' cannot train for ', self.ask_epoch, flush =True)
                    else:
                        print ('you entered ', ans, ' Training will continue to epoch ', self.ask_epoch, flush=True)
                        lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
                        print(f'current LR is  {lr:7.5f}  hit enter to keep  this LR or enter a new LR')
                        ans=input(' ')
                        if ans =='':
                            print (f'keeping current LR of {lr:7.5f}')
                        else:
                            new_lr=float(ans)
                            tf.keras.backend.set_value(self.model.optimizer.lr, new_lr) # set the learning rate in the optimizer
                            print(' changing LR to ', ans)

# %%
epochs=40
ask_epoch=10
ask=LR_ASK(model, epochs,  ask_epoch)
#rlronp=tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2,verbose=1)
#callbacks=[rlronp, ask]
callbacks=[ask]

# %%
new_history=model.fit(x=train_gen,  epochs=epochs, verbose=1, callbacks=callbacks,  validation_data=valid_gen,
               validation_steps=None,  shuffle=False,  initial_epoch=0)
# Out:
# Training will proceed until epoch 10  then you will be asked to
#  enter H to halt training or enter an integer for how many more epochs to run then be asked again
# Epoch 1/40
# 75/75 [==============================] - ETA: 0s - loss: 7.5557 - accuracy: 0.6247
#  validation loss of  6.1706 is below lowest loss, saving weights from epoch 1   as best weights
# 75/75 [==============================] - 137s 1s/step - loss: 7.5557 - accuracy: 0.6247 - val_loss: 6.1706 - val_accuracy: 0.8656
# Epoch 2/40
# 75/75 [==============================] - ETA: 0s - loss: 5.8587 - accuracy: 0.7660
#  validation loss of  5.3667 is below lowest loss, saving weights from epoch 2   as best weights
# 75/75 [==============================] - 86s 1s/step - loss: 5.8587 - accuracy: 0.7660 - val_loss: 5.3667 - val_accuracy: 0.8196
# Epoch 3/40
# 75/75 [==============================] - ETA: 0s - loss: 4.8896 - accuracy: 0.8560
#  validation loss of  4.3788 is below lowest loss, saving weights from epoch 3   as best weights
# 75/75 [==============================] - 87s 1s/step - loss: 4.8896 - accuracy: 0.8560 - val_loss: 4.3788 - val_accuracy: 0.9092
# Epoch 4/40
# 75/75 [==============================] - ETA: 0s - loss: 4.1976 - accuracy: 0.8693
#  validation loss of  3.7783 is below lowest loss, saving weights from epoch 4   as best weights
# 75/75 [==============================] - 86s 1s/step - loss: 4.1976 - accuracy: 0.8693 - val_loss: 3.7783 - val_accuracy: 0.9165
# Epoch 5/40
# 75/75 [==============================] - ETA: 0s - loss: 3.5592 - accuracy: 0.8833
#  validation loss of  3.1794 is below lowest loss, saving weights from epoch 5   as best weights
# 75/75 [==============================] - 86s 1s/step - loss: 3.5592 - accuracy: 0.8833 - val_loss: 3.1794 - val_accuracy: 0.9262
# Epoch 6/40
# 75/75 [==============================] - ETA: 0s - loss: 3.0413 - accuracy: 0.9027
#  validation loss of  2.7296 is below lowest loss, saving weights from epoch 6   as best weights
# 75/75 [==============================] - 86s 1s/step - loss: 3.0413 - accuracy: 0.9027 - val_loss: 2.7296 - val_accuracy: 0.9165
# Epoch 7/40
# 75/75 [==============================] - ETA: 0s - loss: 2.5714 - accuracy: 0.9220
#  validation loss of  2.3995 is below lowest loss, saving weights from epoch 7   as best weights
# 75/75 [==============================] - 87s 1s/step - loss: 2.5714 - accuracy: 0.9220 - val_loss: 2.3995 - val_accuracy: 0.8995
# Epoch 8/40
# 75/75 [==============================] - ETA: 0s - loss: 2.2181 - accuracy: 0.9167
#  validation loss of  2.0487 is below lowest loss, saving weights from epoch 8   as best weights
# 75/75 [==============================] - 86s 1s/step - loss: 2.2181 - accuracy: 0.9167 - val_loss: 2.0487 - val_accuracy: 0.9056
# Epoch 9/40
# 75/75 [==============================] - ETA: 0s - loss: 1.9206 - accuracy: 0.9113
#  validation loss of  1.9410 is below lowest loss, saving weights from epoch 9   as best weights
# 75/75 [==============================] - 86s 1s/step - loss: 1.9206 - accuracy: 0.9113 - val_loss: 1.9410 - val_accuracy: 0.8293
# Epoch 10/40
# 75/75 [==============================] - ETA: 0s - loss: 1.6339 - accuracy: 0.9280
#  validation loss of  1.6103 is below lowest loss, saving weights from epoch 10  as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# 5
# you entered  5  Training will continue to epoch  15
# current LR is  0.00100  hit enter to keep  this LR or enter a new LR
#  0.0005
#  changing LR to  0.0005
# 75/75 [==============================] - 115s 2s/step - loss: 1.6339 - accuracy: 0.9280 - val_loss: 1.6103 - val_accuracy: 0.8729
# Epoch 11/40
# 75/75 [==============================] - ETA: 0s - loss: 1.4128 - accuracy: 0.9380
#  validation loss of  1.3453 is below lowest loss, saving weights from epoch 11  as best weights
# 75/75 [==============================] - 86s 1s/step - loss: 1.4128 - accuracy: 0.9380 - val_loss: 1.3453 - val_accuracy: 0.9322
# Epoch 12/40
# 75/75 [==============================] - ETA: 0s - loss: 1.2823 - accuracy: 0.9507
#  validation loss of  1.3667 is above lowest loss of  1.3453 keeping weights from epoch 11 as best weights
# 75/75 [==============================] - 86s 1s/step - loss: 1.2823 - accuracy: 0.9507 - val_loss: 1.3667 - val_accuracy: 0.8959
# Epoch 13/40
# 75/75 [==============================] - ETA: 0s - loss: 1.1775 - accuracy: 0.9587
#  validation loss of  1.2894 is below lowest loss, saving weights from epoch 13  as best weights
# 75/75 [==============================] - 86s 1s/step - loss: 1.1775 - accuracy: 0.9587 - val_loss: 1.2894 - val_accuracy: 0.8777
# Epoch 14/40
# 75/75 [==============================] - ETA: 0s - loss: 1.0895 - accuracy: 0.9527
#  validation loss of  1.1195 is below lowest loss, saving weights from epoch 14  as best weights
# 75/75 [==============================] - 86s 1s/step - loss: 1.0895 - accuracy: 0.9527 - val_loss: 1.1195 - val_accuracy: 0.9201
# Epoch 15/40
# 75/75 [==============================] - ETA: 0s - loss: 1.0028 - accuracy: 0.9547
#  validation loss of  1.1879 is above lowest loss of  1.1195 keeping weights from epoch 14 as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# 5
# you entered  5  Training will continue to epoch  20
# current LR is  0.00050  hit enter to keep  this LR or enter a new LR
#
# keeping current LR of 0.00050
# 75/75 [==============================] - 100s 1s/step - loss: 1.0028 - accuracy: 0.9547 - val_loss: 1.1879 - val_accuracy: 0.8729
# Epoch 16/40
# 75/75 [==============================] - ETA: 0s - loss: 0.9307 - accuracy: 0.9587
#  validation loss of  1.0402 is below lowest loss, saving weights from epoch 16  as best weights
# 75/75 [==============================] - 87s 1s/step - loss: 0.9307 - accuracy: 0.9587 - val_loss: 1.0402 - val_accuracy: 0.8789
# Epoch 17/40
# 75/75 [==============================] - ETA: 0s - loss: 0.8438 - accuracy: 0.9633
#  validation loss of  0.8587 is below lowest loss, saving weights from epoch 17  as best weights
# 75/75 [==============================] - 87s 1s/step - loss: 0.8438 - accuracy: 0.9633 - val_loss: 0.8587 - val_accuracy: 0.9346
# Epoch 18/40
# 75/75 [==============================] - ETA: 0s - loss: 0.7511 - accuracy: 0.9713
#  validation loss of  0.9423 is above lowest loss of  0.8587 keeping weights from epoch 17 as best weights
# 75/75 [==============================] - 86s 1s/step - loss: 0.7511 - accuracy: 0.9713 - val_loss: 0.9423 - val_accuracy: 0.8898
# Epoch 19/40
# 75/75 [==============================] - ETA: 0s - loss: 0.7064 - accuracy: 0.9640
#  validation loss of  0.8299 is below lowest loss, saving weights from epoch 19  as best weights
# 75/75 [==============================] - 86s 1s/step - loss: 0.7064 - accuracy: 0.9640 - val_loss: 0.8299 - val_accuracy: 0.9007
# Epoch 20/40
# 75/75 [==============================] - ETA: 0s - loss: 0.6189 - accuracy: 0.9747
#  validation loss of  0.6861 is below lowest loss, saving weights from epoch 20  as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# H
# you entered  H  Training halted on epoch  20  due to user input
#
# 75/75 [==============================] - 100s 1s/step - loss: 0.6189 - accuracy: 0.9747 - val_loss: 0.6861 - val_accuracy: 0.9370
# loading model with weights from epoch  20
# training elapsed time was 0.0 hours, 31.0 minutes, 1.96 seconds)

# %%
def predictor(test_gen, test_steps):
    y_pred= []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(test_gen, verbose=1)
    tests=len(preds)    
    for i, p in enumerate(preds):        
        pred_index=np.argmax(p)         
        true_index=test_gen.labels[i]  # labels are integer values        
        if pred_index != true_index: # a misclassification has occurred                                           
            errors=errors + 1
            file=test_gen.filenames[i]            
        y_pred.append(pred_index)
            
    acc=( 1-errors/tests) * 100
    print(f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}')
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    if class_count <=30:
        cm = confusion_matrix(ytrue, ypred )
        # plot the confusion matrix
        plt.figure(figsize=(12, 8))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
        plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4) # create classification report
    print("Classification Report:\n----------------------\n", clr)
    return errors, tests
errors, tests=predictor(test_gen, test_steps)
# Out:
# 23/23 [==============================] - 27s 817ms/step
# there were 109 errors in 1656 tests for an accuracy of  93.42
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#    Stage - I     0.9749    0.9566    0.9657      1382
#   Stage - II     0.7244    0.8251    0.7715       223
#  Stage - III     0.8913    0.8039    0.8454        51
#
#     accuracy                         0.9342      1656
#    macro avg     0.8635    0.8619    0.8608      1656
# weighted avg     0.9386    0.9342    0.9358      1656

# %%
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=1.0)
plt.plot(history.history['val_loss'],'b',linewidth=1.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=10)
plt.xlabel('Epochs ',fontsize=10)
plt.ylabel('Loss',fontsize=10)
plt.title('Loss Curves',fontsize=10)
plt.show()
#Plot the Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=1.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=1.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=10)
plt.xlabel('Epochs ',fontsize=10)
plt.ylabel('Accuracy',fontsize=10)
plt.title('Accuracy Curves',fontsize=10) 
plt.show()

# %%
tf.compat.v1.reset_default_graph()
img_shape=(img_size[0], img_size[1], 3)
model_name='MobileNetV3'
base_model=MobileNetV3Large(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max')

base_model.trainable=True
x=base_model.output
x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
x=Dropout(rate=.4, seed=123)(x)       
output=Dense(class_count, activation='softmax')(x)
model=Model(inputs=base_model.input, outputs=output)
lr=.001 # start with this learning rate
model.compile(Adamax(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 [==============================] - 0s 0us/step

# %%
from tensorflow.keras.applications import MobileNetV3Large

# %%
class LR_ASK(keras.callbacks.Callback):
    def __init__ (self, model, epochs,  ask_epoch): # initialization of the callback
        super(LR_ASK, self).__init__()
        self.model=model               
        self.ask_epoch=ask_epoch
        self.epochs=epochs
        self.ask=True # if True query the user on a specified epoch
        self.lowest_vloss=np.inf
        self.best_weights=self.model.get_weights() # set best weights to model's initial weights
        self.best_epoch=1
        
        
    def on_train_begin(self, logs=None): # this runs on the beginning of training
        if self.ask_epoch == 0: 
            print('you set ask_epoch = 0, ask_epoch will be set to 1', flush=True)
            self.ask_epoch=1
        if self.ask_epoch >= self.epochs: # you are running for epochs but ask_epoch>epochs
            print('ask_epoch >= epochs, will train for ', epochs, ' epochs', flush=True)
            self.ask=False # do not query the user
        if self.epochs == 1:
            self.ask=False # running only for 1 epoch so do not query user
        else:
            print('Training will proceed until epoch', ask_epoch,' then you will be asked to') 
            print(' enter H to halt training or enter an integer for how many more epochs to run then be asked again')  
        self.start_time= time.time() # set the time at which training started
        
    def on_train_end(self, logs=None):   # runs at the end of training  
        print('loading model with weights from epoch ', self.best_epoch)
        self.model.set_weights(self.best_weights) # set the weights of the model to the best weights
        tr_duration=time.time() - self.start_time   # determine how long the training cycle lasted         
        hours = tr_duration // 3600
        minutes = (tr_duration - (hours * 3600)) // 60
        seconds = tr_duration - ((hours * 3600) + (minutes * 60))
        msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
        print (msg, flush=True) # print out training duration time
        
    def on_epoch_end(self, epoch, logs=None):  # method runs on the end of each epoch
        v_loss=logs.get('val_loss')  # get the validation loss for this epoch
        if v_loss< self.lowest_vloss:
            self.lowest_vloss=v_loss
            self.best_weights=self.model.get_weights() # set best weights to model's initial weights
            self.best_epoch=epoch + 1
            print (f'\n validation loss of {v_loss:7.4f} is below lowest loss, saving weights from epoch {str(epoch + 1):3s} as best weights')
        else:
            print (f'\n validation loss of {v_loss:7.4f} is above lowest loss of {self.lowest_vloss:7.4f} keeping weights from epoch {str(self.best_epoch)} as best weights')
        
        if self.ask: # are the conditions right to query the user?
            if epoch + 1 ==self.ask_epoch: # is this epoch the one for quering the user?
                print('\n Enter H to end training or  an integer for the number of additional epochs to run then ask again')
                ans=input()
                
                if ans == 'H' or ans =='h' or ans == '0': # quit training for these conditions
                    print ('you entered ', ans, ' Training halted on epoch ', epoch+1, ' due to user input\n', flush=True)
                    self.model.stop_training = True # halt training
                else: # user wants to continue training
                    self.ask_epoch += int(ans)
                    if self.ask_epoch > self.epochs:
                        print('\nYou specified maximum epochs of as ', self.epochs, ' cannot train for ', self.ask_epoch, flush =True)
                    else:
                        print ('you entered ', ans, ' Training will continue to epoch ', self.ask_epoch, flush=True)
                        lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
                        print(f'current LR is  {lr:7.5f}  hit enter to keep  this LR or enter a new LR')
                        ans=input(' ')
                        if ans =='':
                            print (f'keeping current LR of {lr:7.5f}')
                        else:
                            new_lr=float(ans)
                            tf.keras.backend.set_value(self.model.optimizer.lr, new_lr) # set the learning rate in the optimizer
                            print(' changing LR to ', ans)

# %%
epochs=40
ask_epoch=10
ask=LR_ASK(model, epochs,  ask_epoch)
#rlronp=tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2,verbose=1)
#callbacks=[rlronp, ask]
callbacks=[ask]

# %%
new_history=model.fit(x=train_gen,  epochs=epochs, verbose=1, callbacks=callbacks,  validation_data=valid_gen,
               validation_steps=None,  shuffle=False,  initial_epoch=0)
# Out:
# ask_epoch >= epochs, will train for  40  epochs
# Training will proceed until epoch 10  then you will be asked to
#  enter H to halt training or enter an integer for how many more epochs to run then be asked again
# Epoch 1/40
# 75/75 [==============================] - ETA: 0s - loss: 0.2284 - accuracy: 0.9887
#  validation loss of  0.4956 is above lowest loss of  0.4151 keeping weights from epoch 34 as best weights
# 75/75 [==============================] - 33s 440ms/step - loss: 0.2284 - accuracy: 0.9887 - val_loss: 0.4956 - val_accuracy: 0.8753
# Epoch 2/40
# 75/75 [==============================] - ETA: 0s - loss: 0.2102 - accuracy: 0.9913
#  validation loss of  0.6890 is above lowest loss of  0.4151 keeping weights from epoch 34 as best weights
# 75/75 [==============================] - 22s 296ms/step - loss: 0.2102 - accuracy: 0.9913 - val_loss: 0.6890 - val_accuracy: 0.8245
# Epoch 3/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1999 - accuracy: 0.9907
#  validation loss of  0.4717 is above lowest loss of  0.4151 keeping weights from epoch 34 as best weights
# 75/75 [==============================] - 23s 303ms/step - loss: 0.1999 - accuracy: 0.9907 - val_loss: 0.4717 - val_accuracy: 0.8850
# Epoch 4/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1885 - accuracy: 0.9933
#  validation loss of  0.5509 is above lowest loss of  0.4151 keeping weights from epoch 34 as best weights
# 75/75 [==============================] - 23s 302ms/step - loss: 0.1885 - accuracy: 0.9933 - val_loss: 0.5509 - val_accuracy: 0.8511
# Epoch 5/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1843 - accuracy: 0.9920
#  validation loss of  0.4603 is above lowest loss of  0.4151 keeping weights from epoch 34 as best weights
# 75/75 [==============================] - 25s 339ms/step - loss: 0.1843 - accuracy: 0.9920 - val_loss: 0.4603 - val_accuracy: 0.8874
# Epoch 6/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1799 - accuracy: 0.9920
#  validation loss of  0.4509 is above lowest loss of  0.4151 keeping weights from epoch 34 as best weights
# 75/75 [==============================] - 22s 296ms/step - loss: 0.1799 - accuracy: 0.9920 - val_loss: 0.4509 - val_accuracy: 0.8862
# Epoch 7/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1694 - accuracy: 0.9953
#  validation loss of  0.5572 is above lowest loss of  0.4151 keeping weights from epoch 34 as best weights
# 75/75 [==============================] - 22s 294ms/step - loss: 0.1694 - accuracy: 0.9953 - val_loss: 0.5572 - val_accuracy: 0.8644
# Epoch 8/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1775 - accuracy: 0.9907
#  validation loss of  0.3841 is below lowest loss, saving weights from epoch 8   as best weights
# 75/75 [==============================] - 23s 299ms/step - loss: 0.1775 - accuracy: 0.9907 - val_loss: 0.3841 - val_accuracy: 0.9031
# Epoch 9/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1592 - accuracy: 0.9947
#  validation loss of  0.3725 is below lowest loss, saving weights from epoch 9   as best weights
# 75/75 [==============================] - 24s 316ms/step - loss: 0.1592 - accuracy: 0.9947 - val_loss: 0.3725 - val_accuracy: 0.9044
# Epoch 10/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1525 - accuracy: 0.9960
#  validation loss of  0.4701 is above lowest loss of  0.3725 keeping weights from epoch 9 as best weights
# 75/75 [==============================] - 22s 297ms/step - loss: 0.1525 - accuracy: 0.9960 - val_loss: 0.4701 - val_accuracy: 0.8838
# Epoch 11/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1561 - accuracy: 0.9933
#  validation loss of  0.4962 is above lowest loss of  0.3725 keeping weights from epoch 9 as best weights
# 75/75 [==============================] - 22s 295ms/step - loss: 0.1561 - accuracy: 0.9933 - val_loss: 0.4962 - val_accuracy: 0.8765
# Epoch 12/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.9900
#  validation loss of  0.6414 is above lowest loss of  0.3725 keeping weights from epoch 9 as best weights
# 75/75 [==============================] - 23s 304ms/step - loss: 0.1609 - accuracy: 0.9900 - val_loss: 0.6414 - val_accuracy: 0.8354
# Epoch 13/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1475 - accuracy: 0.9927
#  validation loss of  0.5028 is above lowest loss of  0.3725 keeping weights from epoch 9 as best weights
# 75/75 [==============================] - 22s 292ms/step - loss: 0.1475 - accuracy: 0.9927 - val_loss: 0.5028 - val_accuracy: 0.8753
# Epoch 14/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1368 - accuracy: 0.9973
#  validation loss of  0.5251 is above lowest loss of  0.3725 keeping weights from epoch 9 as best weights
# 75/75 [==============================] - 22s 295ms/step - loss: 0.1368 - accuracy: 0.9973 - val_loss: 0.5251 - val_accuracy: 0.8777
# Epoch 15/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.9953
#  validation loss of  0.3477 is below lowest loss, saving weights from epoch 15  as best weights
# 75/75 [==============================] - 24s 315ms/step - loss: 0.1386 - accuracy: 0.9953 - val_loss: 0.3477 - val_accuracy: 0.9237
# Epoch 16/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1444 - accuracy: 0.9920
#  validation loss of  0.4530 is above lowest loss of  0.3477 keeping weights from epoch 15 as best weights
# 75/75 [==============================] - 22s 297ms/step - loss: 0.1444 - accuracy: 0.9920 - val_loss: 0.4530 - val_accuracy: 0.8995
# Epoch 17/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1395 - accuracy: 0.9907
#  validation loss of  0.4150 is above lowest loss of  0.3477 keeping weights from epoch 15 as best weights
# 75/75 [==============================] - 22s 298ms/step - loss: 0.1395 - accuracy: 0.9907 - val_loss: 0.4150 - val_accuracy: 0.9031
# Epoch 18/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1284 - accuracy: 0.9967
#  validation loss of  0.5058 is above lowest loss of  0.3477 keeping weights from epoch 15 as best weights
# 75/75 [==============================] - 22s 297ms/step - loss: 0.1284 - accuracy: 0.9967 - val_loss: 0.5058 - val_accuracy: 0.8814
# Epoch 19/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1245 - accuracy: 0.9980
#  validation loss of  0.5010 is above lowest loss of  0.3477 keeping weights from epoch 15 as best weights
# 75/75 [==============================] - 22s 295ms/step - loss: 0.1245 - accuracy: 0.9980 - val_loss: 0.5010 - val_accuracy: 0.8753
# Epoch 20/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1369 - accuracy: 0.9927
#  validation loss of  0.4110 is above lowest loss of  0.3477 keeping weights from epoch 15 as best weights
# 75/75 [==============================] - 22s 296ms/step - loss: 0.1369 - accuracy: 0.9927 - val_loss: 0.4110 - val_accuracy: 0.9080
# Epoch 21/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1365 - accuracy: 0.9920
#  validation loss of  0.6168 is above lowest loss of  0.3477 keeping weights from epoch 15 as best weights
# 75/75 [==============================] - 23s 311ms/step - loss: 0.1365 - accuracy: 0.9920 - val_loss: 0.6168 - val_accuracy: 0.8450
# Epoch 22/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1228 - accuracy: 0.9967
#  validation loss of  0.4746 is above lowest loss of  0.3477 keeping weights from epoch 15 as best weights
# 75/75 [==============================] - 22s 297ms/step - loss: 0.1228 - accuracy: 0.9967 - val_loss: 0.4746 - val_accuracy: 0.8826
# Epoch 23/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1210 - accuracy: 0.9967
#  validation loss of  0.3471 is below lowest loss, saving weights from epoch 23  as best weights
# 75/75 [==============================] - 23s 305ms/step - loss: 0.1210 - accuracy: 0.9967 - val_loss: 0.3471 - val_accuracy: 0.9274
# Epoch 24/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1174 - accuracy: 0.9953
#  validation loss of  0.3289 is below lowest loss, saving weights from epoch 24  as best weights
# 75/75 [==============================] - 22s 298ms/step - loss: 0.1174 - accuracy: 0.9953 - val_loss: 0.3289 - val_accuracy: 0.9310
# Epoch 25/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1213 - accuracy: 0.9947
#  validation loss of  0.3761 is above lowest loss of  0.3289 keeping weights from epoch 24 as best weights
# 75/75 [==============================] - 24s 313ms/step - loss: 0.1213 - accuracy: 0.9947 - val_loss: 0.3761 - val_accuracy: 0.9128
# Epoch 26/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1171 - accuracy: 0.9980
#  validation loss of  0.3650 is above lowest loss of  0.3289 keeping weights from epoch 24 as best weights
# 75/75 [==============================] - 22s 298ms/step - loss: 0.1171 - accuracy: 0.9980 - val_loss: 0.3650 - val_accuracy: 0.9068
# Epoch 27/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1100 - accuracy: 0.9980
#  validation loss of  0.3461 is above lowest loss of  0.3289 keeping weights from epoch 24 as best weights
# 75/75 [==============================] - 23s 304ms/step - loss: 0.1100 - accuracy: 0.9980 - val_loss: 0.3461 - val_accuracy: 0.9189
# Epoch 28/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1140 - accuracy: 0.9960
#  validation loss of  0.3877 is above lowest loss of  0.3289 keeping weights from epoch 24 as best weights
# 75/75 [==============================] - 23s 304ms/step - loss: 0.1140 - accuracy: 0.9960 - val_loss: 0.3877 - val_accuracy: 0.9140
# Epoch 29/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1138 - accuracy: 0.9967
#  validation loss of  0.3827 is above lowest loss of  0.3289 keeping weights from epoch 24 as best weights
# 75/75 [==============================] - 26s 347ms/step - loss: 0.1138 - accuracy: 0.9967 - val_loss: 0.3827 - val_accuracy: 0.9140
# Epoch 30/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1084 - accuracy: 0.9980
#  validation loss of  0.3697 is above lowest loss of  0.3289 keeping weights from epoch 24 as best weights
# 75/75 [==============================] - 22s 296ms/step - loss: 0.1084 - accuracy: 0.9980 - val_loss: 0.3697 - val_accuracy: 0.9177
# Epoch 31/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1083 - accuracy: 0.9960
#  validation loss of  0.4005 is above lowest loss of  0.3289 keeping weights from epoch 24 as best weights
# 75/75 [==============================] - 22s 297ms/step - loss: 0.1083 - accuracy: 0.9960 - val_loss: 0.4005 - val_accuracy: 0.9044
# Epoch 32/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1075 - accuracy: 0.9967
#  validation loss of  0.3673 is above lowest loss of  0.3289 keeping weights from epoch 24 as best weights
# 75/75 [==============================] - 23s 299ms/step - loss: 0.1075 - accuracy: 0.9967 - val_loss: 0.3673 - val_accuracy: 0.9068
# Epoch 33/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1076 - accuracy: 0.9960
#  validation loss of  0.4096 is above lowest loss of  0.3289 keeping weights from epoch 24 as best weights
# 75/75 [==============================] - 24s 313ms/step - loss: 0.1076 - accuracy: 0.9960 - val_loss: 0.4096 - val_accuracy: 0.9031
# Epoch 34/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1161 - accuracy: 0.9940
#  validation loss of  0.4454 is above lowest loss of  0.3289 keeping weights from epoch 24 as best weights
# 75/75 [==============================] - 22s 298ms/step - loss: 0.1161 - accuracy: 0.9940 - val_loss: 0.4454 - val_accuracy: 0.8898
# Epoch 35/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1083 - accuracy: 0.9953
#  validation loss of  0.4534 is above lowest loss of  0.3289 keeping weights from epoch 24 as best weights
# 75/75 [==============================] - 22s 298ms/step - loss: 0.1083 - accuracy: 0.9953 - val_loss: 0.4534 - val_accuracy: 0.8862
# Epoch 36/40
# 75/75 [==============================] - ETA: 0s - loss: 0.1075 - accuracy: 0.9960
#  validation loss of  0.6176 is above lowest loss of  0.3289 keeping weights from epoch 24 as best weights
# 75/75 [==============================] - 22s 297ms/step - loss: 0.1075 - accuracy: 0.9960 - val_loss: 0.6176 - val_accuracy: 0.8450
# Epoch 37/40
# 75/75 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9993
#  validation loss of  0.3695 is above lowest loss of  0.3289 keeping weights from epoch 24 as best weights
# 75/75 [==============================] - 22s 298ms/step - loss: 0.0958 - accuracy: 0.9993 - val_loss: 0.3695 - val_accuracy: 0.9153
# Epoch 38/40
# 75/75 [==============================] - ETA: 0s - loss: 0.0984 - accuracy: 0.9980
#  validation loss of  0.3475 is above lowest loss of  0.3289 keeping weights from epoch 24 as best weights
# 75/75 [==============================] - 22s 296ms/step - loss: 0.0984 - accuracy: 0.9980 - val_loss: 0.3475 - val_accuracy: 0.9201
# Epoch 39/40
# 75/75 [==============================] - ETA: 0s - loss: 0.0976 - accuracy: 0.9967
#  validation loss of  0.3293 is above lowest loss of  0.3289 keeping weights from epoch 24 as best weights
# 75/75 [==============================] - 22s 298ms/step - loss: 0.0976 - accuracy: 0.9967 - val_loss: 0.3293 - val_accuracy: 0.9213
# Epoch 40/40
# 75/75 [==============================] - ETA: 0s - loss: 0.0971 - accuracy: 0.9973
#  validation loss of  0.3557 is above lowest loss of  0.3289 keeping weights from epoch 24 as best weights
# 75/75 [==============================] - 23s 302ms/step - loss: 0.0971 - accuracy: 0.9973 - val_loss: 0.3557 - val_accuracy: 0.9201
# loading model with weights from epoch  24
# training elapsed time was 0.0 hours, 16.0 minutes, 35.95 seconds)

# %%
def predictor(test_gen, test_steps):
    y_pred= []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(test_gen, verbose=1)
    tests=len(preds)    
    for i, p in enumerate(preds):        
        pred_index=np.argmax(p)         
        true_index=test_gen.labels[i]  # labels are integer values        
        if pred_index != true_index: # a misclassification has occurred                                           
            errors=errors + 1
            file=test_gen.filenames[i]            
        y_pred.append(pred_index)
            
    acc=( 1-errors/tests) * 100
    print(f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}')
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    if class_count <=30:
        cm = confusion_matrix(ytrue, ypred )
        # plot the confusion matrix
        plt.figure(figsize=(12, 8))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
        plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4) # create classification report
    print("Classification Report:\n----------------------\n", clr)
    return errors, tests
errors, tests=predictor(test_gen, test_steps)
# Out:
# 23/23 [==============================] - 5s 198ms/step
# there were 111 errors in 1656 tests for an accuracy of  93.30
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#    Stage - I     0.9778    0.9573    0.9675      1382
#   Stage - II     0.7344    0.7937    0.7629       223
#  Stage - III     0.7258    0.8824    0.7965        51
#
#     accuracy                         0.9330      1656
#    macro avg     0.8127    0.8778    0.8423      1656
# weighted avg     0.9373    0.9330    0.9347      1656

# %%
plt.figure(figsize=[8,6])
plt.plot(new_history.history['loss'],'r',linewidth=1.0)
plt.plot(new_history.history['val_loss'],'b',linewidth=1.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=10)
plt.xlabel('Epochs ',fontsize=10)
plt.ylabel('Loss',fontsize=10)
plt.title('Loss Curves',fontsize=10)
plt.show()
#Plot the Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(new_history.history['accuracy'],'r',linewidth=1.0)
plt.plot(new_history.history['val_accuracy'],'b',linewidth=1.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=10)
plt.xlabel('Epochs ',fontsize=10)
plt.ylabel('Accuracy',fontsize=10)
plt.title('Accuracy Curves',fontsize=10) 
plt.show()

# %%
from tensorflow.keras.applications import NASNetLarge
img_shape=(img_size[0], img_size[1], 3)
model_name='NASNetLarge'
base_model=tf.keras.applications.NASNetLarge(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max') 
# Note you are always told NOT to make the base model trainable initially- that is WRONG you get better results leaving it trainable
base_model.trainable=True
x=base_model.output
x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
x=Dropout(rate=.4, seed=123)(x)       
output=Dense(class_count, activation='softmax')(x)
model=Model(inputs=base_model.input, outputs=output)
lr=.001 # start with this learning rate
model.compile(Adamax(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-c24b8e64759e> in <module>
#       2 img_shape=(img_size[0], img_size[1], 3)
#       3 model_name='NASNetLarge'
# ----> 4 base_model=tf.keras.applications.NASNetLarge(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max')
#       5 # Note you are always told NOT to make the base model trainable initially- that is WRONG you get better results leaving it trainable
#       6 base_model.trainable=True
#
# /usr/local/lib/python3.8/dist-packages/keras/applications/nasnet.py in NASNetLarge(input_shape, include_top, weights, input_tensor, pooling, classes, classifier_activation)
#     474           backend that does not support separable convolutions.
#     475   """
# --> 476   return NASNet(
#     477       input_shape,
#     478       penultimate_filters=4032,
#
# /usr/local/lib/python3.8/dist-packages/keras/applications/nasnet.py in NASNet(input_shape, penultimate_filters, num_blocks, stem_block_filters, skip_reduction, filter_multiplier, include_top, weights, input_tensor, pooling, classes, default_size, classifier_activation)
#     172
#     173   # Determine proper input shape and default size.
# --> 174   input_shape = imagenet_utils.obtain_input_shape(
#     175       input_shape,
#     176       default_size=default_size,
#
# /usr/local/lib/python3.8/dist-packages/keras/applications/imagenet_utils.py in obtain_input_shape(input_shape, default_size, min_size, data_format, require_flatten, weights)
#     347     if input_shape is not None:
#     348       if input_shape != default_shape:
# --> 349         raise ValueError('When setting `include_top=True` '
#     350                          'and loading `imagenet` weights, '
#     351                          f'`input_shape` should be {default_shape}.  '
#
# ValueError: When setting `include_top=True` and loading `imagenet` weights, `input_shape` should be (331, 331, 3).  Received: input_shape=(224, 224, 3)

# %%
class LR_ASK(keras.callbacks.Callback):
    def __init__ (self, model, epochs,  ask_epoch): # initialization of the callback
        super(LR_ASK, self).__init__()
        self.model=model               
        self.ask_epoch=ask_epoch
        self.epochs=epochs
        self.ask=True # if True query the user on a specified epoch
        self.lowest_vloss=np.inf
        self.best_weights=self.model.get_weights() # set best weights to model's initial weights
        self.best_epoch=1
        
        
    def on_train_begin(self, logs=None): # this runs on the beginning of training
        if self.ask_epoch == 0: 
            print('you set ask_epoch = 0, ask_epoch will be set to 1', flush=True)
            self.ask_epoch=1
        if self.ask_epoch >= self.epochs: # you are running for epochs but ask_epoch>epochs
            print('ask_epoch >= epochs, will train for ', epochs, ' epochs', flush=True)
            self.ask=False # do not query the user
        if self.epochs == 1:
            self.ask=False # running only for 1 epoch so do not query user
        else:
            print('Training will proceed until epoch', ask_epoch,' then you will be asked to') 
            print(' enter H to halt training or enter an integer for how many more epochs to run then be asked again')  
        self.start_time= time.time() # set the time at which training started
        
    def on_train_end(self, logs=None):   # runs at the end of training  
        print('loading model with weights from epoch ', self.best_epoch)
        self.model.set_weights(self.best_weights) # set the weights of the model to the best weights
        tr_duration=time.time() - self.start_time   # determine how long the training cycle lasted         
        hours = tr_duration // 3600
        minutes = (tr_duration - (hours * 3600)) // 60
        seconds = tr_duration - ((hours * 3600) + (minutes * 60))
        msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
        print (msg, flush=True) # print out training duration time
        
    def on_epoch_end(self, epoch, logs=None):  # method runs on the end of each epoch
        v_loss=logs.get('val_loss')  # get the validation loss for this epoch
        if v_loss< self.lowest_vloss:
            self.lowest_vloss=v_loss
            self.best_weights=self.model.get_weights() # set best weights to model's initial weights
            self.best_epoch=epoch + 1
            print (f'\n validation loss of {v_loss:7.4f} is below lowest loss, saving weights from epoch {str(epoch + 1):3s} as best weights')
        else:
            print (f'\n validation loss of {v_loss:7.4f} is above lowest loss of {self.lowest_vloss:7.4f} keeping weights from epoch {str(self.best_epoch)} as best weights')
        
        if self.ask: # are the conditions right to query the user?
            if epoch + 1 ==self.ask_epoch: # is this epoch the one for quering the user?
                print('\n Enter H to end training or  an integer for the number of additional epochs to run then ask again')
                ans=input()
                
                if ans == 'H' or ans =='h' or ans == '0': # quit training for these conditions
                    print ('you entered ', ans, ' Training halted on epoch ', epoch+1, ' due to user input\n', flush=True)
                    self.model.stop_training = True # halt training
                else: # user wants to continue training
                    self.ask_epoch += int(ans)
                    if self.ask_epoch > self.epochs:
                        print('\nYou specified maximum epochs of as ', self.epochs, ' cannot train for ', self.ask_epoch, flush =True)
                    else:
                        print ('you entered ', ans, ' Training will continue to epoch ', self.ask_epoch, flush=True)
                        lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
                        print(f'current LR is  {lr:7.5f}  hit enter to keep  this LR or enter a new LR')
                        ans=input(' ')
                        if ans =='':
                            print (f'keeping current LR of {lr:7.5f}')
                        else:
                            new_lr=float(ans)
                            tf.keras.backend.set_value(self.model.optimizer.lr, new_lr) # set the learning rate in the optimizer
                            print(' changing LR to ', ans)

# %%
epochs=100
ask_epoch=40
ask=LR_ASK(model, epochs,  ask_epoch)
#rlronp=tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2,verbose=1)
#callbacks=[rlronp, ask]
callbacks=[ask]

# %%
history=model.fit(x=train_gen,  epochs=epochs, verbose=1, callbacks=callbacks,  validation_data=valid_gen,
               validation_steps=None,  shuffle=False,  initial_epoch=0)

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
img_shape=(img_size[0], img_size[1], 3)
model_name='ResNet50'
base_model=tf.keras.applications.ResNet50(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max') 
# Note you are always told NOT to make the base model trainable initially- that is WRONG you get better results leaving it trainable
base_model.trainable=True
x=base_model.output
x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
x=Dropout(rate=.4, seed=123)(x)       
output=Dense(class_count, activation='softmax')(x)
model=Model(inputs=base_model.input, outputs=output)
lr=.001 # start with this learning rate
model.compile(Adamax(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
class LR_ASK(keras.callbacks.Callback):
    def __init__ (self, model, epochs,  ask_epoch): # initialization of the callback
        super(LR_ASK, self).__init__()
        self.model=model               
        self.ask_epoch=ask_epoch
        self.epochs=epochs
        self.ask=True # if True query the user on a specified epoch
        self.lowest_vloss=np.inf
        self.best_weights=self.model.get_weights() # set best weights to model's initial weights
        self.best_epoch=1
        
        
    def on_train_begin(self, logs=None): # this runs on the beginning of training
        if self.ask_epoch == 0: 
            print('you set ask_epoch = 0, ask_epoch will be set to 1', flush=True)
            self.ask_epoch=1
        if self.ask_epoch >= self.epochs: # you are running for epochs but ask_epoch>epochs
            print('ask_epoch >= epochs, will train for ', epochs, ' epochs', flush=True)
            self.ask=False # do not query the user
        if self.epochs == 1:
            self.ask=False # running only for 1 epoch so do not query user
        else:
            print('Training will proceed until epoch', ask_epoch,' then you will be asked to') 
            print(' enter H to halt training or enter an integer for how many more epochs to run then be asked again')  
        self.start_time= time.time() # set the time at which training started
        
    def on_train_end(self, logs=None):   # runs at the end of training  
        print('loading model with weights from epoch ', self.best_epoch)
        self.model.set_weights(self.best_weights) # set the weights of the model to the best weights
        tr_duration=time.time() - self.start_time   # determine how long the training cycle lasted         
        hours = tr_duration // 3600
        minutes = (tr_duration - (hours * 3600)) // 60
        seconds = tr_duration - ((hours * 3600) + (minutes * 60))
        msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
        print (msg, flush=True) # print out training duration time
        
    def on_epoch_end(self, epoch, logs=None):  # method runs on the end of each epoch
        v_loss=logs.get('val_loss')  # get the validation loss for this epoch
        if v_loss< self.lowest_vloss:
            self.lowest_vloss=v_loss
            self.best_weights=self.model.get_weights() # set best weights to model's initial weights
            self.best_epoch=epoch + 1
            print (f'\n validation loss of {v_loss:7.4f} is below lowest loss, saving weights from epoch {str(epoch + 1):3s} as best weights')
        else:
            print (f'\n validation loss of {v_loss:7.4f} is above lowest loss of {self.lowest_vloss:7.4f} keeping weights from epoch {str(self.best_epoch)} as best weights')
        
        if self.ask: # are the conditions right to query the user?
            if epoch + 1 ==self.ask_epoch: # is this epoch the one for quering the user?
                print('\n Enter H to end training or  an integer for the number of additional epochs to run then ask again')
                ans=input()
                
                if ans == 'H' or ans =='h' or ans == '0': # quit training for these conditions
                    print ('you entered ', ans, ' Training halted on epoch ', epoch+1, ' due to user input\n', flush=True)
                    self.model.stop_training = True # halt training
                else: # user wants to continue training
                    self.ask_epoch += int(ans)
                    if self.ask_epoch > self.epochs:
                        print('\nYou specified maximum epochs of as ', self.epochs, ' cannot train for ', self.ask_epoch, flush =True)
                    else:
                        print ('you entered ', ans, ' Training will continue to epoch ', self.ask_epoch, flush=True)
                        lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
                        print(f'current LR is  {lr:7.5f}  hit enter to keep  this LR or enter a new LR')
                        ans=input(' ')
                        if ans =='':
                            print (f'keeping current LR of {lr:7.5f}')
                        else:
                            new_lr=float(ans)
                            tf.keras.backend.set_value(self.model.optimizer.lr, new_lr) # set the learning rate in the optimizer
                            print(' changing LR to ', ans)

# %%
epochs=100
ask_epoch=40
ask=LR_ASK(model, epochs,  ask_epoch)
#rlronp=tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2,verbose=1)
#callbacks=[rlronp, ask]
callbacks=[ask]

# %%
history=model.fit(x=train_gen,  epochs=epochs, verbose=1, callbacks=callbacks,  validation_data=valid_gen,
               validation_steps=None,  shuffle=False,  initial_epoch=0)

# %%
def predictor(test_gen, test_steps):
    y_pred= []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(test_gen, verbose=1)
    tests=len(preds)    
    for i, p in enumerate(preds):        
        pred_index=np.argmax(p)         
        true_index=test_gen.labels[i]  # labels are integer values        
        if pred_index != true_index: # a misclassification has occurred                                           
            errors=errors + 1
            file=test_gen.filenames[i]            
        y_pred.append(pred_index)
            
    acc=( 1-errors/tests) * 100
    print(f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}')
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    if class_count <=30:
        cm = confusion_matrix(ytrue, ypred )
        # plot the confusion matrix
        plt.figure(figsize=(12, 8))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
        plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4) # create classification report
    print("Classification Report:\n----------------------\n", clr)
    return errors, tests
errors, tests=predictor(test_gen, test_steps)
# Out:
# 23/23 [==============================] - 6s 231ms/step
# there were 442 errors in 1656 tests for an accuracy of  73.31
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#    Stage - I     0.7766    0.8888    0.8289       935
#   Stage - II     0.6054    0.3982    0.4804       447
#  Stage - III     0.7000    0.7848    0.7400       223
#   Stage - IV     0.7143    0.5882    0.6452        51
#
#     accuracy                         0.7331      1656
#    macro avg     0.6991    0.6650    0.6736      1656
# weighted avg     0.7182    0.7331    0.7172      1656

# %%
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=1.0)
plt.plot(history.history['val_loss'],'b',linewidth=1.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=10)
plt.xlabel('Epochs ',fontsize=10)
plt.ylabel('Loss',fontsize=10)
plt.title('Loss Curves',fontsize=10)
plt.show()
#Plot the Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=1.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=1.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=10)
plt.xlabel('Epochs ',fontsize=10)
plt.ylabel('Accuracy',fontsize=10)
plt.title('Accuracy Curves',fontsize=10) 
plt.show()

# %%
from tensorflow.keras.applications.vgg16 import VGG16
img_shape=(img_size[0], img_size[1], 3)
model_name='VGG16'
base_model=tf.keras.applications.VGG16(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max') 
# Note you are always told NOT to make the base model trainable initially- that is WRONG you get better results leaving it trainable
base_model.trainable=True
x=base_model.output
x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
x=Dropout(rate=.4, seed=123)(x)       
output=Dense(class_count, activation='softmax')(x)
model=Model(inputs=base_model.input, outputs=output)
lr=.001 # start with this learning rate
model.compile(Adamax(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step

# %%
class LR_ASK(keras.callbacks.Callback):
    def __init__ (self, model, epochs,  ask_epoch): # initialization of the callback
        super(LR_ASK, self).__init__()
        self.model=model               
        self.ask_epoch=ask_epoch
        self.epochs=epochs
        self.ask=True # if True query the user on a specified epoch
        self.lowest_vloss=np.inf
        self.best_weights=self.model.get_weights() # set best weights to model's initial weights
        self.best_epoch=1
        
        
    def on_train_begin(self, logs=None): # this runs on the beginning of training
        if self.ask_epoch == 0: 
            print('you set ask_epoch = 0, ask_epoch will be set to 1', flush=True)
            self.ask_epoch=1
        if self.ask_epoch >= self.epochs: # you are running for epochs but ask_epoch>epochs
            print('ask_epoch >= epochs, will train for ', epochs, ' epochs', flush=True)
            self.ask=False # do not query the user
        if self.epochs == 1:
            self.ask=False # running only for 1 epoch so do not query user
        else:
            print('Training will proceed until epoch', ask_epoch,' then you will be asked to') 
            print(' enter H to halt training or enter an integer for how many more epochs to run then be asked again')  
        self.start_time= time.time() # set the time at which training started
        
    def on_train_end(self, logs=None):   # runs at the end of training  
        print('loading model with weights from epoch ', self.best_epoch)
        self.model.set_weights(self.best_weights) # set the weights of the model to the best weights
        tr_duration=time.time() - self.start_time   # determine how long the training cycle lasted         
        hours = tr_duration // 3600
        minutes = (tr_duration - (hours * 3600)) // 60
        seconds = tr_duration - ((hours * 3600) + (minutes * 60))
        msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
        print (msg, flush=True) # print out training duration time
        
    def on_epoch_end(self, epoch, logs=None):  # method runs on the end of each epoch
        v_loss=logs.get('val_loss')  # get the validation loss for this epoch
        if v_loss< self.lowest_vloss:
            self.lowest_vloss=v_loss
            self.best_weights=self.model.get_weights() # set best weights to model's initial weights
            self.best_epoch=epoch + 1
            print (f'\n validation loss of {v_loss:7.4f} is below lowest loss, saving weights from epoch {str(epoch + 1):3s} as best weights')
        else:
            print (f'\n validation loss of {v_loss:7.4f} is above lowest loss of {self.lowest_vloss:7.4f} keeping weights from epoch {str(self.best_epoch)} as best weights')
        
        if self.ask: # are the conditions right to query the user?
            if epoch + 1 ==self.ask_epoch: # is this epoch the one for quering the user?
                print('\n Enter H to end training or  an integer for the number of additional epochs to run then ask again')
                ans=input()
                
                if ans == 'H' or ans =='h' or ans == '0': # quit training for these conditions
                    print ('you entered ', ans, ' Training halted on epoch ', epoch+1, ' due to user input\n', flush=True)
                    self.model.stop_training = True # halt training
                else: # user wants to continue training
                    self.ask_epoch += int(ans)
                    if self.ask_epoch > self.epochs:
                        print('\nYou specified maximum epochs of as ', self.epochs, ' cannot train for ', self.ask_epoch, flush =True)
                    else:
                        print ('you entered ', ans, ' Training will continue to epoch ', self.ask_epoch, flush=True)
                        lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
                        print(f'current LR is  {lr:7.5f}  hit enter to keep  this LR or enter a new LR')
                        ans=input(' ')
                        if ans =='':
                            print (f'keeping current LR of {lr:7.5f}')
                        else:
                            new_lr=float(ans)
                            tf.keras.backend.set_value(self.model.optimizer.lr, new_lr) # set the learning rate in the optimizer
                            print(' changing LR to ', ans)

# %%
epochs=100
ask_epoch=5
ask=LR_ASK(model, epochs,  ask_epoch)
#rlronp=tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2,verbose=1)
#callbacks=[rlronp, ask]
callbacks=[ask]

# %%
history=model.fit(x=train_gen,  epochs=epochs, verbose=1, callbacks=callbacks,  validation_data=valid_gen,
               validation_steps=None,  shuffle=False,  initial_epoch=0)
# Out:
# Training will proceed until epoch 5  then you will be asked to
#  enter H to halt training or enter an integer for how many more epochs to run then be asked again
# Epoch 1/100
# 75/75 [==============================] - ETA: 0s - loss: 5.6148 - accuracy: 0.4420
#  validation loss of 10.9556 is below lowest loss, saving weights from epoch 1   as best weights
# 75/75 [==============================] - 1383s 18s/step - loss: 5.6148 - accuracy: 0.4420 - val_loss: 10.9556 - val_accuracy: 0.0424
# Epoch 2/100
# 75/75 [==============================] - ETA: 0s - loss: 4.1278 - accuracy: 0.5193
#  validation loss of  5.1091 is below lowest loss, saving weights from epoch 2   as best weights
# 75/75 [==============================] - 30s 392ms/step - loss: 4.1278 - accuracy: 0.5193 - val_loss: 5.1091 - val_accuracy: 0.8390
# Epoch 3/100
# 75/75 [==============================] - ETA: 0s - loss: 3.4065 - accuracy: 0.5353
#  validation loss of  3.2689 is below lowest loss, saving weights from epoch 3   as best weights
# 75/75 [==============================] - 31s 412ms/step - loss: 3.4065 - accuracy: 0.5353 - val_loss: 3.2689 - val_accuracy: 0.8354
# Epoch 4/100
# 75/75 [==============================] - ETA: 0s - loss: 2.8843 - accuracy: 0.5840
#  validation loss of  2.6947 is below lowest loss, saving weights from epoch 4   as best weights
# 75/75 [==============================] - 29s 385ms/step - loss: 2.8843 - accuracy: 0.5840 - val_loss: 2.6947 - val_accuracy: 0.8390
# Epoch 5/100
# 75/75 [==============================] - ETA: 0s - loss: 2.4989 - accuracy: 0.6180
#  validation loss of  2.3964 is below lowest loss, saving weights from epoch 5   as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# 10
# you entered  10  Training will continue to epoch  15
# current LR is  0.00100  hit enter to keep  this LR or enter a new LR
#  0.0005
#  changing LR to  0.0005
# 75/75 [==============================] - 70s 933ms/step - loss: 2.4989 - accuracy: 0.6180 - val_loss: 2.3964 - val_accuracy: 0.8390
# Epoch 6/100
# 75/75 [==============================] - ETA: 0s - loss: 2.2226 - accuracy: 0.6453
#  validation loss of  1.9710 is below lowest loss, saving weights from epoch 6   as best weights
# 75/75 [==============================] - 31s 407ms/step - loss: 2.2226 - accuracy: 0.6453 - val_loss: 1.9710 - val_accuracy: 0.8390
# Epoch 7/100
# 75/75 [==============================] - ETA: 0s - loss: 2.0661 - accuracy: 0.6647
#  validation loss of  1.8974 is below lowest loss, saving weights from epoch 7   as best weights
# 75/75 [==============================] - 29s 387ms/step - loss: 2.0661 - accuracy: 0.6647 - val_loss: 1.8974 - val_accuracy: 0.8136
# Epoch 8/100
# 75/75 [==============================] - ETA: 0s - loss: 1.9286 - accuracy: 0.6693
#  validation loss of  1.7315 is below lowest loss, saving weights from epoch 8   as best weights
# 75/75 [==============================] - 29s 385ms/step - loss: 1.9286 - accuracy: 0.6693 - val_loss: 1.7315 - val_accuracy: 0.8402
# Epoch 9/100
# 75/75 [==============================] - ETA: 0s - loss: 1.8148 - accuracy: 0.6867
#  validation loss of  1.6265 is below lowest loss, saving weights from epoch 9   as best weights
# 75/75 [==============================] - 31s 413ms/step - loss: 1.8148 - accuracy: 0.6867 - val_loss: 1.6265 - val_accuracy: 0.8390
# Epoch 10/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6909 - accuracy: 0.6920
#  validation loss of  1.4936 is below lowest loss, saving weights from epoch 10  as best weights
# 75/75 [==============================] - 29s 388ms/step - loss: 1.6909 - accuracy: 0.6920 - val_loss: 1.4936 - val_accuracy: 0.8390
# Epoch 11/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5927 - accuracy: 0.7160
#  validation loss of  1.4145 is below lowest loss, saving weights from epoch 11  as best weights
# 75/75 [==============================] - 31s 416ms/step - loss: 1.5927 - accuracy: 0.7160 - val_loss: 1.4145 - val_accuracy: 0.8680
# Epoch 12/100
# 75/75 [==============================] - ETA: 0s - loss: 1.4969 - accuracy: 0.7273
#  validation loss of  1.3180 is below lowest loss, saving weights from epoch 12  as best weights
# 75/75 [==============================] - 29s 387ms/step - loss: 1.4969 - accuracy: 0.7273 - val_loss: 1.3180 - val_accuracy: 0.8838
# Epoch 13/100
# 75/75 [==============================] - ETA: 0s - loss: 1.4024 - accuracy: 0.7467
#  validation loss of  2.2826 is above lowest loss of  1.3180 keeping weights from epoch 12 as best weights
# 75/75 [==============================] - 30s 402ms/step - loss: 1.4024 - accuracy: 0.7467 - val_loss: 2.2826 - val_accuracy: 0.5145
# Epoch 14/100
# 75/75 [==============================] - ETA: 0s - loss: 1.3231 - accuracy: 0.7600
#  validation loss of  1.1450 is below lowest loss, saving weights from epoch 14  as best weights
# 75/75 [==============================] - 30s 400ms/step - loss: 1.3231 - accuracy: 0.7600 - val_loss: 1.1450 - val_accuracy: 0.8547
# Epoch 15/100
# 75/75 [==============================] - ETA: 0s - loss: 1.2387 - accuracy: 0.7700
#  validation loss of  1.2377 is above lowest loss of  1.1450 keeping weights from epoch 14 as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# 5
# you entered  5  Training will continue to epoch  20
# current LR is  0.00050  hit enter to keep  this LR or enter a new LR
#
# keeping current LR of 0.00050
# 75/75 [==============================] - 78s 1s/step - loss: 1.2387 - accuracy: 0.7700 - val_loss: 1.2377 - val_accuracy: 0.8475
# Epoch 16/100
# 75/75 [==============================] - ETA: 0s - loss: 1.1799 - accuracy: 0.7753
#  validation loss of  0.9898 is below lowest loss, saving weights from epoch 16  as best weights
# 75/75 [==============================] - 31s 404ms/step - loss: 1.1799 - accuracy: 0.7753 - val_loss: 0.9898 - val_accuracy: 0.8656
# Epoch 17/100
# 75/75 [==============================] - ETA: 0s - loss: 1.1206 - accuracy: 0.7840
#  validation loss of  1.0928 is above lowest loss of  0.9898 keeping weights from epoch 16 as best weights
# 75/75 [==============================] - 30s 399ms/step - loss: 1.1206 - accuracy: 0.7840 - val_loss: 1.0928 - val_accuracy: 0.8438
# Epoch 18/100
# 75/75 [==============================] - ETA: 0s - loss: 1.0782 - accuracy: 0.7800
#  validation loss of  0.9171 is below lowest loss, saving weights from epoch 18  as best weights
# 75/75 [==============================] - 29s 384ms/step - loss: 1.0782 - accuracy: 0.7800 - val_loss: 0.9171 - val_accuracy: 0.8559
# Epoch 19/100
# 75/75 [==============================] - ETA: 0s - loss: 1.0169 - accuracy: 0.7900
#  validation loss of  0.9436 is above lowest loss of  0.9171 keeping weights from epoch 18 as best weights
# 75/75 [==============================] - 31s 411ms/step - loss: 1.0169 - accuracy: 0.7900 - val_loss: 0.9436 - val_accuracy: 0.8523
# Epoch 20/100
# 75/75 [==============================] - ETA: 0s - loss: 0.9529 - accuracy: 0.8053
#  validation loss of  1.1652 is above lowest loss of  0.9171 keeping weights from epoch 18 as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# H
# you entered  H  Training halted on epoch  20  due to user input
#
# 75/75 [==============================] - 47s 630ms/step - loss: 0.9529 - accuracy: 0.8053 - val_loss: 1.1652 - val_accuracy: 0.7724
# loading model with weights from epoch  18
# training elapsed time was 0.0 hours, 34.0 minutes, 21.88 seconds)

# %%
1def predictor(test_gen, test_steps):
    y_pred= []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(test_gen, verbose=1)
    tests=len(preds)    
    for i, p in enumerate(preds):        
        pred_index=np.argmax(p)         
        true_index=test_gen.labels[i]  # labels are integer values        
        if pred_index != true_index: # a misclassification has occurred                                           
            errors=errors + 1
            file=test_gen.filenames[i]            
        y_pred.append(pred_index)
            
    acc=( 1-errors/tests) * 100
    print(f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}')
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    if class_count <=30:
        cm = confusion_matrix(ytrue, ypred )
        # plot the confusion matrix
        plt.figure(figsize=(12, 8))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
        plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4) # create classification report
    print("Classification Report:\n----------------------\n", clr)
    return errors, tests
errors, tests=predictor(test_gen, test_steps)
# Out:
# 23/23 [==============================] - 9s 420ms/step
# there were 206 errors in 1656 tests for an accuracy of  87.56
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#    Stage - I     0.8831    0.9949    0.9357      1382
#   Stage - II     0.8481    0.3004    0.4437       223
#  Stage - III     0.4000    0.1569    0.2254        51
#
#     accuracy                         0.8756      1656
#    macro avg     0.7104    0.4841    0.5349      1656
# weighted avg     0.8635    0.8756    0.8476      1656

# %%
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=1.0)
plt.plot(history.history['val_loss'],'b',linewidth=1.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=10)
plt.xlabel('Epochs ',fontsize=10)
plt.ylabel('Loss',fontsize=10)
plt.title('Loss Curves',fontsize=10)
plt.show()
#Plot the Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=1.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=1.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=10)
plt.xlabel('Epochs ',fontsize=10)
plt.ylabel('Accuracy',fontsize=10)
plt.title('Accuracy Curves',fontsize=10) 
plt.show()

# %%
from tensorflow.keras.applications import InceptionV3
img_shape=(img_size[0], img_size[1], 3)
model_name='Googlenet'
base_model=tf.keras.applications.InceptionV3(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max') 
# Note you are always told NOT to make the base model trainable initially- that is WRONG you get better results leaving it trainable
base_model.trainable=True
x=base_model.output
x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
x=Dropout(rate=.4, seed=123)(x)       
output=Dense(class_count, activation='softmax')(x)
model=Model(inputs=base_model.input, outputs=output)
lr=.001 # start with this learning rate
model.compile(Adamax(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 5s 0us/step

# %%
class LR_ASK(keras.callbacks.Callback):
    def __init__ (self, model, epochs,  ask_epoch): # initialization of the callback
        super(LR_ASK, self).__init__()
        self.model=model               
        self.ask_epoch=ask_epoch
        self.epochs=epochs
        self.ask=True # if True query the user on a specified epoch
        self.lowest_vloss=np.inf
        self.best_weights=self.model.get_weights() # set best weights to model's initial weights
        self.best_epoch=1
        
        
    def on_train_begin(self, logs=None): # this runs on the beginning of training
        if self.ask_epoch == 0: 
            print('you set ask_epoch = 0, ask_epoch will be set to 1', flush=True)
            self.ask_epoch=1
        if self.ask_epoch >= self.epochs: # you are running for epochs but ask_epoch>epochs
            print('ask_epoch >= epochs, will train for ', epochs, ' epochs', flush=True)
            self.ask=False # do not query the user
        if self.epochs == 1:
            self.ask=False # running only for 1 epoch so do not query user
        else:
            print('Training will proceed until epoch', ask_epoch,' then you will be asked to') 
            print(' enter H to halt training or enter an integer for how many more epochs to run then be asked again')  
        self.start_time= time.time() # set the time at which training started
        
    def on_train_end(self, logs=None):   # runs at the end of training  
        print('loading model with weights from epoch ', self.best_epoch)
        self.model.set_weights(self.best_weights) # set the weights of the model to the best weights
        tr_duration=time.time() - self.start_time   # determine how long the training cycle lasted         
        hours = tr_duration // 3600
        minutes = (tr_duration - (hours * 3600)) // 60
        seconds = tr_duration - ((hours * 3600) + (minutes * 60))
        msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
        print (msg, flush=True) # print out training duration time
        
    def on_epoch_end(self, epoch, logs=None):  # method runs on the end of each epoch
        v_loss=logs.get('val_loss')  # get the validation loss for this epoch
        if v_loss< self.lowest_vloss:
            self.lowest_vloss=v_loss
            self.best_weights=self.model.get_weights() # set best weights to model's initial weights
            self.best_epoch=epoch + 1
            print (f'\n validation loss of {v_loss:7.4f} is below lowest loss, saving weights from epoch {str(epoch + 1):3s} as best weights')
        else:
            print (f'\n validation loss of {v_loss:7.4f} is above lowest loss of {self.lowest_vloss:7.4f} keeping weights from epoch {str(self.best_epoch)} as best weights')
        
        if self.ask: # are the conditions right to query the user?
            if epoch + 1 ==self.ask_epoch: # is this epoch the one for quering the user?
                print('\n Enter H to end training or  an integer for the number of additional epochs to run then ask again')
                ans=input()
                
                if ans == 'H' or ans =='h' or ans == '0': # quit training for these conditions
                    print ('you entered ', ans, ' Training halted on epoch ', epoch+1, ' due to user input\n', flush=True)
                    self.model.stop_training = True # halt training
                else: # user wants to continue training
                    self.ask_epoch += int(ans)
                    if self.ask_epoch > self.epochs:
                        print('\nYou specified maximum epochs of as ', self.epochs, ' cannot train for ', self.ask_epoch, flush =True)
                    else:
                        print ('you entered ', ans, ' Training will continue to epoch ', self.ask_epoch, flush=True)
                        lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
                        print(f'current LR is  {lr:7.5f}  hit enter to keep  this LR or enter a new LR')
                        ans=input(' ')
                        if ans =='':
                            print (f'keeping current LR of {lr:7.5f}')
                        else:
                            new_lr=float(ans)
                            tf.keras.backend.set_value(self.model.optimizer.lr, new_lr) # set the learning rate in the optimizer
                            print(' changing LR to ', ans)

# %%
epochs=100
ask_epoch=10
ask=LR_ASK(model, epochs,  ask_epoch)
#rlronp=tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2,verbose=1)
#callbacks=[rlronp, ask]
callbacks=[ask]

# %%
history=model.fit(x=train_gen,  epochs=epochs, verbose=1, callbacks=callbacks,  validation_data=valid_gen,
               validation_steps=None,  shuffle=False,  initial_epoch=0)
# Out:
# Training will proceed until epoch 10  then you will be asked to
#  enter H to halt training or enter an integer for how many more epochs to run then be asked again
# Epoch 1/100
# 75/75 [==============================] - ETA: 0s - loss: 8.4637 - accuracy: 0.5720
#  validation loss of 806.3221 is below lowest loss, saving weights from epoch 1   as best weights
# 75/75 [==============================] - 35s 341ms/step - loss: 8.4637 - accuracy: 0.5720 - val_loss: 806.3221 - val_accuracy: 0.1610
# Epoch 2/100
# 75/75 [==============================] - ETA: 0s - loss: 6.9303 - accuracy: 0.7493
#  validation loss of 11.3387 is below lowest loss, saving weights from epoch 2   as best weights
# 75/75 [==============================] - 26s 349ms/step - loss: 6.9303 - accuracy: 0.7493 - val_loss: 11.3387 - val_accuracy: 0.5569
# Epoch 3/100
# 75/75 [==============================] - ETA: 0s - loss: 6.1444 - accuracy: 0.8053
#  validation loss of  5.5252 is below lowest loss, saving weights from epoch 3   as best weights
# 75/75 [==============================] - 24s 313ms/step - loss: 6.1444 - accuracy: 0.8053 - val_loss: 5.5252 - val_accuracy: 0.8269
# Epoch 4/100
# 75/75 [==============================] - ETA: 0s - loss: 5.3333 - accuracy: 0.8340
#  validation loss of  4.9227 is below lowest loss, saving weights from epoch 4   as best weights
# 75/75 [==============================] - 25s 339ms/step - loss: 5.3333 - accuracy: 0.8340 - val_loss: 4.9227 - val_accuracy: 0.8910
# Epoch 5/100
# 75/75 [==============================] - ETA: 0s - loss: 4.8211 - accuracy: 0.8480
#  validation loss of  4.3154 is below lowest loss, saving weights from epoch 5   as best weights
# 75/75 [==============================] - 24s 317ms/step - loss: 4.8211 - accuracy: 0.8480 - val_loss: 4.3154 - val_accuracy: 0.9044
# Epoch 6/100
# 75/75 [==============================] - ETA: 0s - loss: 4.5343 - accuracy: 0.8413
#  validation loss of  4.0839 is below lowest loss, saving weights from epoch 6   as best weights
# 75/75 [==============================] - 23s 312ms/step - loss: 4.5343 - accuracy: 0.8413 - val_loss: 4.0839 - val_accuracy: 0.8596
# Epoch 7/100
# 75/75 [==============================] - ETA: 0s - loss: 4.0483 - accuracy: 0.8593
#  validation loss of  3.6140 is below lowest loss, saving weights from epoch 7   as best weights
# 75/75 [==============================] - 24s 316ms/step - loss: 4.0483 - accuracy: 0.8593 - val_loss: 3.6140 - val_accuracy: 0.9140
# Epoch 8/100
# 75/75 [==============================] - ETA: 0s - loss: 3.5718 - accuracy: 0.8787
#  validation loss of  3.2248 is below lowest loss, saving weights from epoch 8   as best weights
# 75/75 [==============================] - 24s 316ms/step - loss: 3.5718 - accuracy: 0.8787 - val_loss: 3.2248 - val_accuracy: 0.9201
# Epoch 9/100
# 75/75 [==============================] - ETA: 0s - loss: 3.2007 - accuracy: 0.8947
#  validation loss of  3.1804 is below lowest loss, saving weights from epoch 9   as best weights
# 75/75 [==============================] - 24s 314ms/step - loss: 3.2007 - accuracy: 0.8947 - val_loss: 3.1804 - val_accuracy: 0.8184
# Epoch 10/100
# 75/75 [==============================] - ETA: 0s - loss: 2.9121 - accuracy: 0.8913
#  validation loss of  2.9249 is below lowest loss, saving weights from epoch 10  as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# 5
# you entered  5  Training will continue to epoch  15
# current LR is  0.00100  hit enter to keep  this LR or enter a new LR
#  0.0005
#  changing LR to  0.0005
# 75/75 [==============================] - 147s 2s/step - loss: 2.9121 - accuracy: 0.8913 - val_loss: 2.9249 - val_accuracy: 0.8438
# Epoch 11/100
# 75/75 [==============================] - ETA: 0s - loss: 2.6298 - accuracy: 0.9093
#  validation loss of  2.5638 is below lowest loss, saving weights from epoch 11  as best weights
# 75/75 [==============================] - 24s 312ms/step - loss: 2.6298 - accuracy: 0.9093 - val_loss: 2.5638 - val_accuracy: 0.9165
# Epoch 12/100
# 75/75 [==============================] - ETA: 0s - loss: 2.4769 - accuracy: 0.9247
#  validation loss of  2.5662 is above lowest loss of  2.5638 keeping weights from epoch 11 as best weights
# 75/75 [==============================] - 24s 313ms/step - loss: 2.4769 - accuracy: 0.9247 - val_loss: 2.5662 - val_accuracy: 0.8777
# Epoch 13/100
# 75/75 [==============================] - ETA: 0s - loss: 2.3880 - accuracy: 0.8967
#  validation loss of  2.3901 is below lowest loss, saving weights from epoch 13  as best weights
# 75/75 [==============================] - 26s 348ms/step - loss: 2.3880 - accuracy: 0.8967 - val_loss: 2.3901 - val_accuracy: 0.8692
# Epoch 14/100
# 75/75 [==============================] - ETA: 0s - loss: 2.2015 - accuracy: 0.9367
#  validation loss of  2.2139 is below lowest loss, saving weights from epoch 14  as best weights
# 75/75 [==============================] - 24s 313ms/step - loss: 2.2015 - accuracy: 0.9367 - val_loss: 2.2139 - val_accuracy: 0.8935
# Epoch 15/100
# 75/75 [==============================] - ETA: 0s - loss: 2.1314 - accuracy: 0.9040
#  validation loss of  2.1737 is below lowest loss, saving weights from epoch 15  as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# 5
# you entered  5  Training will continue to epoch  20
# current LR is  0.00050  hit enter to keep  this LR or enter a new LR
#
# keeping current LR of 0.00050
# 75/75 [==============================] - 39s 519ms/step - loss: 2.1314 - accuracy: 0.9040 - val_loss: 2.1737 - val_accuracy: 0.8741
# Epoch 16/100
# 75/75 [==============================] - ETA: 0s - loss: 1.9704 - accuracy: 0.9360
#  validation loss of  1.9827 is below lowest loss, saving weights from epoch 16  as best weights
# 75/75 [==============================] - 24s 315ms/step - loss: 1.9704 - accuracy: 0.9360 - val_loss: 1.9827 - val_accuracy: 0.9080
# Epoch 17/100
# 75/75 [==============================] - ETA: 0s - loss: 1.8473 - accuracy: 0.9347
#  validation loss of  1.9331 is below lowest loss, saving weights from epoch 17  as best weights
# 75/75 [==============================] - 24s 317ms/step - loss: 1.8473 - accuracy: 0.9347 - val_loss: 1.9331 - val_accuracy: 0.9128
# Epoch 18/100
# 75/75 [==============================] - ETA: 0s - loss: 1.7513 - accuracy: 0.9267
#  validation loss of  1.9111 is below lowest loss, saving weights from epoch 18  as best weights
# 75/75 [==============================] - 23s 312ms/step - loss: 1.7513 - accuracy: 0.9267 - val_loss: 1.9111 - val_accuracy: 0.8511
# Epoch 19/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6455 - accuracy: 0.9380
#  validation loss of  1.6730 is below lowest loss, saving weights from epoch 19  as best weights
# 75/75 [==============================] - 24s 313ms/step - loss: 1.6455 - accuracy: 0.9380 - val_loss: 1.6730 - val_accuracy: 0.9031
# Epoch 20/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5342 - accuracy: 0.9413
#  validation loss of  1.7643 is above lowest loss of  1.6730 keeping weights from epoch 19 as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# H
# you entered  H  Training halted on epoch  20  due to user input
#
# 75/75 [==============================] - 45s 600ms/step - loss: 1.5342 - accuracy: 0.9413 - val_loss: 1.7643 - val_accuracy: 0.8063
# loading model with weights from epoch  19
# training elapsed time was 0.0 hours, 10.0 minutes, 51.62 seconds)

# %%
def predictor(test_gen, test_steps):
    y_pred= []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(test_gen, verbose=1)
    tests=len(preds)    
    for i, p in enumerate(preds):        
        pred_index=np.argmax(p)         
        true_index=test_gen.labels[i]  # labels are integer values        
        if pred_index != true_index: # a misclassification has occurred                                           
            errors=errors + 1
            file=test_gen.filenames[i]            
        y_pred.append(pred_index)
            
    acc=( 1-errors/tests) * 100
    print(f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}')
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    if class_count <=30:
        cm = confusion_matrix(ytrue, ypred )
        # plot the confusion matrix
        plt.figure(figsize=(12, 8))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
        plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4) # create classification report
    print("Classification Report:\n----------------------\n", clr)
    return errors, tests
errors, tests=predictor(test_gen, test_steps)
# Out:
# 23/23 [==============================] - 5s 209ms/step
# there were 146 errors in 1656 tests for an accuracy of  91.18
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#    Stage - I     0.9808    0.9219    0.9504      1382
#   Stage - II     0.6316    0.8610    0.7287       223
#  Stage - III     0.8302    0.8627    0.8462        51
#
#     accuracy                         0.9118      1656
#    macro avg     0.8142    0.8819    0.8417      1656
# weighted avg     0.9291    0.9118    0.9173      1656

# %%
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=1.0)
plt.plot(history.history['val_loss'],'b',linewidth=1.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=10)
plt.xlabel('Epochs ',fontsize=10)
plt.ylabel('Loss',fontsize=10)
plt.title('Loss Curves',fontsize=10)
plt.show()
#Plot the Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=1.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=1.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=10)
plt.xlabel('Epochs ',fontsize=10)
plt.ylabel('Accuracy',fontsize=10)
plt.title('Accuracy Curves',fontsize=10) 
plt.show()
